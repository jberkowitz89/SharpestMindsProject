# %% [markdown]
# # Scraping Link3710 with BeautifulSoup

# %%
#importing necessary libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#URL link for user Link3710
url = "https://www.nintendolife.com/users/link3710/games"
r = requests.get(url)

# %%
#formatting as soup
html_text = r.text

soup = BeautifulSoup(html_text, "html.parser")

# %%
#Checking out the head
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en-GB">
# <head>
# <base href="https://www.nintendolife.com"/>
# <meta content="ccms/0.2.0 (dgpCMS: http://nlife.com)" name="generator"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>link3710 - Games Collection - Nintendo Life</title>
# <meta content="#e60012" name="theme-color">
# <meta content="#e60012" name="msapplication-navbutton-color">
# <meta content="#e60012" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="D7560F5739AF48D918517B5AFC24A564" name="msvalidate.01"/>
# <meta content="Nintendo Life" name="author"/>
# <meta content="Nintendo Life" name="apple-mobile-web-app-title"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0" id="viewport" name="viewport"/>
# <meta content="noindex,nofollow" name="robots"/>
# <meta content="135109439853732" property="fb:app_id"/>
# <meta content="link3710" property="og:title"/>
# <meta content="https://images.nintendolife.com/users/58197/1280x720.jpg" data-page-subject="true" property="og:image"/>
# <meta content="http://www.nintendolife.com/users/58197" property="og:url"/>
# <meta content="Nintendo Life" property="og:site_name"/>
# <link href="https://static.nintendolife.com/themes/v12/css/forms.css?accent=%23e60012&amp;v=1568888307" rel="stylesheet" type="text/css"/>
# <link href="https://static.nintendolife.com/themes/nl.v10/css/stylesheet.css?accent=%23e60012&amp;v=1579882328" rel="stylesheet" type="text/css"/>
# <link href="https://static.nintendolife.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://images.nintendolife.com/site/icon/57x57.png" rel="apple-touch-icon" type="image/png"/>
# <link href="https://images.nintendolife.com/site/icon/72x72.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
# <link href="https://images.nintendolife.com/site/icon/114x114.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
# <link href="https://images.nintendolife.com/site/icon/144x144.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
# <link href="https://www.nintendolife.com/opensearch.xml" rel="search" title="Nintendo Life Search" type="application/opensearchdescription+xml"/>
# <link href="http://www.nintendolife.com/users/link3710/games" rel="canonical"/>
# <script type="text/javascript">var dgpLoaded = false; var dgpTools = false; var gdpr = false; var dfp_npa = "false"; var dfp_uam = true; var dgpReady = function () { if (!dgpLoaded && dgpTools) { dgpLoaded = true; if (!dfp_uam) { jQuery('div[data-dfp-id$=STICKY_LB]').remove(); } try { jQuery('div[data-dfp-id]:not(.lazyload)').getDFPads({"custom_variables":{"source":"index","version":"hd","tags":["switch","wiiu","3ds","wii","eshop"],"games":[]},"acceptable_ads_show":true,"lazyload_selector":"div[data-dfp-id].lazyload","lazyload_spacer":jQuery(window).width() >= 800 ? 400 : 500,"showNonPersonalisedAds":dfp_npa,"runUAM":dfp_uam,"adRenderedCallback":slotCallback}); } catch(e) { yafaIt(); } } }</script>
# <script src="https://static.nintendolife.com/themes/v12/javascript/jquery.js?v=1568888307" type="text/javascript"></script>
# <script defer="defer" src="https://static.nintendolife.com/themes/v12/javascript/jquery.dgp.js?v=1579604060" type="text/javascript"></script>
# <script type="text/javascript">if (document.cookie.match(/device=desktop/) || navigator.userAgent.match(/iPad/i) || (navigator.userAgent.match(/Safari/i) && !navigator.userAgent.match(/iPhone/i) && navigator.userAgent.match(/Version\/(13|14|15)/i)) || (navigator.userAgent.match(/Android/i) && screen.width >= 800 && !navigator.userAgent.match(/Mobile/i)) || (screen.width > window.innerWidth && screen.width > 800 && !navigator.userAgent.match(/Android|iPhone/i))) { document.getElementById("viewport").setAttribute("content","width=1275"); }</script>
# <script type="text/javascript">var dgpConfig = {"fancybox":false,"lazyload":false,"transaction":"user/games","user":{"user":false,"title":"Guest"}};</script>
# <script type="text/javascript">function mormontLoaded () { mormont('configure', 'property', "nintendolife.com"); mormont('set', "section","user"); mormont('set', "language","en"); mormont('send', 'pageview'); };</script>
# <script async="async" onload="mormontLoaded()" src="//cdn.gamer-network.net/2017/scripts/mormont/v2.9/mormont.js" type="text/javascript"></script>
# <!--[if lt IE 9]><script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script><![endif]-->
# <script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-585082-1', '.nintendolife.com');
# ga('set','dimension1', 'user/games');
# ga('set','dimension2', 'guest');
# ga('send', 'pageview');
# ga('create', 'UA-44691239-1', '.nintendolife.com','gn');
# ga('gn.send', 'pageview');
# 	</script>
# </meta></meta></head>
# <body class="with-hero with-sidebar site-nintendolife device-desktop" data-subject="users/58197">
# <div id="fb-root"></div>
# <div class="template" id="template">
# <div class="header-wrap accent-bg">
# <header class="header" id="header">
# <nav class="menubar">
# <div class="headerbar"><ul id="toolbar">
# <li class="ui-button"><a class="ui-toggle-overlay" data-overlay="sidebar" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-bars"></span><span class="label">Menu</span></a></li>
# <li class="ui-button"><a class="ui-toggle-search" href="search" rel="nofollow"><span class="icon icon-search"></span><span class="label">Search</span></a>
# </li>
# </ul>
# <ul id="controlbar"><li class="ui-button"><a class="ui-share-page optional" href="share" rel="nofollow" title="Share This Page"><span class="icon icon-share"></span> <span class="label">Share</span></a><ul><li><a class="ui-share-page whatsapp" data-service="whatsapp" href="#" rel="nofollow" title="Share this page on WhatsApp"><span class="icon icon-whatsapp"></span></a></li><li><a class="ui-share-page messenger for-mobile" data-service="fbmessenger" href="#" rel="nofollow" title="Share this page on Facebook Messenger"><span class="icon icon-messenger"></span></a></li><li><a class="ui-share-page facebook" data-service="facebook" href="#" rel="nofollow" title="Share this page on Facebook"><span class="icon icon-facebook"></span></a></li><li><a class="ui-share-page twitter" data-service="twitter" href="#" rel="nofollow" title="Share this page on Twitter"><span class="icon icon-twitter"></span></a></li><li><a class="ui-share-page skype" data-service="skype" href="#" rel="nofollow" title="Share this page on Skype"><span class="icon icon-skype"></span></a></li><li><a class="ui-share-page reddit for-desktop" data-service="reddit" href="#" rel="nofollow" title="Share this page on reddit"><span class="icon icon-reddit"></span></a></li></ul></li><li class="ui-toggle-overlay ui-userinfo" data-overlay="userbar"><p class="avatar"><a href="login" rel="nofollow"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></a></p><p class="username optional">Guest</p><p class="subtitle optional"><a href="login" rel="nofollow">Login</a> or <a href="register" rel="nofollow">Sign Up</a></p></li></ul><p class="site-title"><a href="https://www.nintendolife.com/"><img alt="Nintendo Life" src="https://images.nintendolife.com/site/logo.svg?v=2&amp;colour=e60012" width="265"/></a></p>
# </div><form action="search" id="quick-search" method="get">
# <div class="controls"><label>Keywords</label> <input autocomplete="off" class="query textbox" id="query" name="q" placeholder="Search..." type="text"/> <input class="button" name="submit" type="submit" value="Go"/></div>
# </form>
# <div id="quick-search-results"><div id="search-results"></div></div><!-- cache: html:nintendolife.com/nintendolife.com.ssl/menu @ 2020-01-27T00:40:25+00:00 --><div class="ui-menus">
# <div class="accent-bg">
# <div class="accent-wrap">
# <div class="inset">
# <ul id="menu">
# <li><a class="main-menu-item" href="https://www.nintendolife.com/" title="Home"><span class="icon icon-wiiu-home"></span> <span class="label">Home</span></a></li><li class="has-submenu"><a class="main-menu-item no-icon" data-name="topics" href="topics"><span class="label ui-topic-title">Topics</span> <span class="icon icon-caret-down"></span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="news" href="/news"><span class="icon icon-news optional"></span> <span class="label">News</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="reviews" href="/reviews"><span class="icon icon-reviews optional"></span> <span class="label">Reviews</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="features" href="/features"><span class="icon icon-features optional"></span> <span class="label">Features</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="games" href="/games/browse"><span class="icon icon-books optional"></span> <span class="label">Games</span></a></li><li><a class="main-menu-item" data-name="guides" href="/guides"><span class="icon icon-map optional"></span> <span class="label">Guides</span></a></li><li><a class="main-menu-item external" href="https://www.youtube.com/nintendolife"><span class="icon icon-videos optional"></span> <span class="label">Videos</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="forums" href="/forums"><span class="icon icon-comments optional"></span> <span class="label">Forums</span></a></li></ul>
# </div>
# </div>
# </div>
# <div id="submenus"></div></div></nav><nav class="ui-overlays"><section class="ui-overlay" id="userbar"><div class="buffer"><p class="avatar"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></p><p><a class="username ui-user-profile" href="user/profile" rel="nofollow">Guest</a></p><p class="subtitle"><a href="login" rel="nofollow">Login</a> or <a href="register" rel="nofollow">Sign Up</a></p></div><div class="scroll"><div class="body"><ul><li><a class="ui-user-notifications" href="user/notifications" rel="nofollow" title="Number of unread notifications"><span class="icon icon-notification"></span> <span class="label">Notifications</span> <span class="counter accent-bg">0</span></a></li><li><a class="ui-user-games" href="user/games" rel="nofollow"><span class="icon icon-books"></span> <span class="label">Games Collection</span> <span class="icon icon-angle-right right"></span></a></li><li><a class="ui-user-profile" href="user/profile" rel="nofollow"><span class="icon icon-profile"></span> <span class="label">View Profile</span> <span class="icon icon-angle-right right"></span></a></li></ul><ul><li><a href="user" rel="nofollow"><span class="icon icon-settings"></span> <span class="label">Your Account</span> <span class="icon icon-angle-right right"></span></a></li><li><a href="logout" rel="nofollow"><span class="icon icon-logout"></span> <span class="label">Logout</span> <span class="icon icon-angle-right right"></span></a></li></ul></div></div></section><section class="ui-overlay" id="sidebar"><div class="buffer"></div><div class="scroll"><div class="body"><ul class="optional"><li><a href="https://www.nintendolife.com/"><span class="icon icon-wiiu-home"></span> <span class="label">Home</span> <span class="icon icon-angle-right right"></span></a></li></ul><ul class="ui-user-hubs"><li><a href="topics" rel="nofollow"><span class="icon icon-topic"></span> <span class="label">Choose Topics...</span> <span class="icon icon-angle-right right"></span></a></li></ul><ul class="ui-user-manage-hubs"><li><a href="topics" rel="nofollow"><span class="icon icon-settings"></span> <span class="label">Manage Topics</span> <span class="icon icon-angle-right right"></span></a></li></ul></div></div></section></nav><div class="flash"></div></header></div><div class="page" id="page"><div class="masthead inset"><div class="insert for-desktop"><div data-dfp-id="NL_LB_1" data-dfp-sizes="1280x250,1260x110,970x250,960x250,728x90" data-ghost-zone="31" id="r5e2e31b350ccb"></div>
# </div></div><div class="content-wrapper"><section class="hero"><div class="hero-wrap"><div class="background accent-bg no-artwork"></div><div class="accent-bg"><div class="inset"><div class="hero-title with-avatar"><p class="image accent-bg"><img alt="link3710" height="200" src="https://images.nintendolife.com/users/58197/200x200.jpg?v=1516306053" width="200"/></p>
# <h1 class="title"><a href="/users/link3710">link3710</a> </h1>
# <h2 class="heading">User</h2>
# </div><ul class="linkbar"><li class="first"><a href="/users/link3710">Profile</a></li><li><a class="current" href="/users/link3710/games">Games</a></li><li><a href="/users/link3710/comments">Comments</a></li><li><a href="/users/link3710/topics">Discussions</a></li><li class="last"><a href="login">Posts</a></li></ul>
# </div></div></div></section><div class="inset"><div id="body"><div class="content" id="content">
# <section class="container type-user-games with-filters" data-default-style="tile" data-limit="60" data-offset="0" data-param="id=games-collection&amp;sort=date&amp;status=own&amp;type=user-games&amp;user=users%2f58197&amp;view=games" data-style="tile" data-styles="tile" id="listing-games-collection"><nav class="ui-listing-filters"><form action="users/link3710/games" method="get"><h2 class="heading">Filter <span class="icon icon-caret-down"></span></h2>
# <div class="ui-listing-filters-body"><div class="ui-listing-filter ui-listing-filter-collapse"><input autocomplete="off" class="ui-filter-search" data-filter="title" name="title" placeholder="Search..." type="text" value=""/></div><div class="ui-listing-filter"><h3 class="heading">Status<span class="icon icon-caret-down"></span></h3>
# <div class="ui-filter-options">
# <span class="fm-checkbox fm-checkbox-selected"><input checked="checked" class="radio" id="status-opt1" name="status[]" type="checkbox" value="own"> <label class="checkbox" for="status-opt1">Have <span class="count">189</span></label></input></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt2" name="status[]" type="checkbox" value="owned"/> <label class="checkbox" for="status-opt2">Owned <span class="count">2</span></label></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt3" name="status[]" type="checkbox" value="want"/> <label class="checkbox" for="status-opt3">Want <span class="count">103</span></label></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt4" name="status[]" type="checkbox" value="maybe"/> <label class="checkbox" for="status-opt4">Maybe <span class="count">124</span></label></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt5" name="status[]" type="checkbox" value="not-interested"/> <label class="checkbox" for="status-opt5">Nope! <span class="count">86</span></label></span> </div></div><div class="ui-listing-filter ui-listing-filter-collapse"><h3 class="heading">Score<span class="icon icon-caret-left"></span></h3>
# <div class="ui-filter-options">
# <span class="fm-checkbox"><input class="radio" id="score-opt1" name="score[]" type="checkbox" value="10"/> <label class="checkbox" for="score-opt1">10/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt2" name="score[]" type="checkbox" value="9"/> <label class="checkbox" for="score-opt2">9/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt3" name="score[]" type="checkbox" value="8"/> <label class="checkbox" for="score-opt3">8/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt4" name="score[]" type="checkbox" value="7"/> <label class="checkbox" for="score-opt4">7/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt5" name="score[]" type="checkbox" value="6"/> <label class="checkbox" for="score-opt5">6/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt6" name="score[]" type="checkbox" value="5"/> <label class="checkbox" for="score-opt6">5/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt7" name="score[]" type="checkbox" value="4"/> <label class="checkbox" for="score-opt7">4/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt8" name="score[]" type="checkbox" value="3"/> <label class="checkbox" for="score-opt8">3/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt9" name="score[]" type="checkbox" value="2"/> <label class="checkbox" for="score-opt9">2/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt10" name="score[]" type="checkbox" value="1"/> <label class="checkbox" for="score-opt10">1/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt11" name="score[]" type="checkbox" value="none"/> <label class="checkbox" for="score-opt11">No Score</label></span> </div></div><div class="ui-listing-filter ui-listing-filter-collapse"><h3 class="heading">System<span class="icon icon-caret-left"></span></h3>
# <div class="ui-filter-options">
# <span class="fm-checkbox"><input class="radio" id="system-opt1" name="system[]" type="checkbox" value="systems/3ds"/> <label class="checkbox" for="system-opt1">3DS (157)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt2" name="system[]" type="checkbox" value="systems/nintendo-switch"/> <label class="checkbox" for="system-opt2">Switch (156)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt3" name="system[]" type="checkbox" value="systems/switch-eshop"/> <label class="checkbox" for="system-opt3">Switch eShop (80)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt4" name="system[]" type="checkbox" value="systems/wiiu"/> <label class="checkbox" for="system-opt4">Wii U (38)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt5" name="system[]" type="checkbox" value="systems/gameboy"/> <label class="checkbox" for="system-opt5">GB (18)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt6" name="system[]" type="checkbox" value="systems/wii"/> <label class="checkbox" for="system-opt6">Wii (16)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt7" name="system[]" type="checkbox" value="systems/ds"/> <label class="checkbox" for="system-opt7">DS (10)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt8" name="system[]" type="checkbox" value="systems/new-3ds"/> <label class="checkbox" for="system-opt8">New 3DS (10)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt9" name="system[]" type="checkbox" value="systems/3ds-eshop"/> <label class="checkbox" for="system-opt9">3DS eShop (6)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt10" name="system[]" type="checkbox" value="systems/gamecube"/> <label class="checkbox" for="system-opt10">GCN (6)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt11" name="system[]" type="checkbox" value="systems/wiiu-eshop"/> <label class="checkbox" for="system-opt11">Wii U eShop (4)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt12" name="system[]" type="checkbox" value="systems/gbc"/> <label class="checkbox" for="system-opt12">GBC (2)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt13" name="system[]" type="checkbox" value="systems/mobile"/> <label class="checkbox" for="system-opt13">Mobile (1)</label></span> </div></div></div><noscript><input name="submit" type="submit" value="Search"/></noscript></form></nav><nav class="ui-views"><div class="ui-listing-toggles"><select class="select ui-listing-sorts" id="sort" name="sort">
# <option selected="selected" value="date">Release Date</option>
# <option value="added">Added</option>
# <option value="score">User Score</option>
# <option value="rating">Rating</option>
# <option value="title">Title</option>
# </select> <select class="select ui-listing-styles" id="style" name="style">
# <option selected="selected" value="tile">Tile</option>
# </select> </div><ul class="panels"><li class="first last"><a class="selected accent accent-border" data-view="games" href="users/link3710/games#games">Games</a></li></ul>
# </nav><div class="ui-listing-body"><ul class="items cols-3 style-tile"><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/daemon_x_machina" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/daemon_x_machina"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/daemon_x_machina/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/daemon_x_machina"><span class="title accent-hover">Daemon X Machina</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/spyro_reignited_trilogy" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/spyro_reignited_trilogy"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/spyro_reignited_trilogy/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/spyro_reignited_trilogy"><span class="title accent-hover">Spyro Reignited Trilogy</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/gato_roboto" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/gato_roboto"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/gato_roboto/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/gato_roboto"><span class="title accent-hover">Gato Roboto</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/deltarune_chapter_1" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/deltarune_chapter_1"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/deltarune_chapter_1/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/deltarune_chapter_1"><span class="title accent-hover">DELTARUNE Chapter 1</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/super_smash_bros_ultimate" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/super_smash_bros_ultimate"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/super_smash_bros_ultimate/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/super_smash_bros_ultimate"><span class="title accent-hover">Super Smash Bros. Ultimate</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/katamari_damacy_reroll" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/katamari_damacy_reroll"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/katamari_damacy_reroll/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/katamari_damacy_reroll"><span class="title accent-hover">Katamari Damacy REROLL</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/horizon_chase_turbo" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/horizon_chase_turbo"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/horizon_chase_turbo/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/horizon_chase_turbo"><span class="title accent-hover">Horizon Chase Turbo</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/dragon_ball_fighterz" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/dragon_ball_fighterz"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/dragon_ball_fighterz/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/dragon_ball_fighterz"><span class="title accent-hover">Dragon Ball FighterZ</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/undertale" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/undertale"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/undertale/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/undertale"><span class="title accent-hover">Undertale</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/okami_hd" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/okami_hd"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/okami_hd/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/okami_hd"><span class="title accent-hover">Okami HD</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/yokus_island_express" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/yokus_island_express"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/yokus_island_express/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/yokus_island_express"><span class="title accent-hover">Yoku's Island Express</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/bayonetta_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/bayonetta_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/bayonetta_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/bayonetta_2"><span class="title accent-hover">Bayonetta 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/bayonetta" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/bayonetta"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/bayonetta/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/bayonetta"><span class="title accent-hover">Bayonetta</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lost_sphear" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lost_sphear"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lost_sphear/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lost_sphear"><span class="title accent-hover">Lost Sphear</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/xenoblade_chronicles_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/xenoblade_chronicles_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/xenoblade_chronicles_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/xenoblade_chronicles_2"><span class="title accent-hover">Xenoblade Chronicles 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/mobile/animal_crossing_pocket_camp" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/mobile/animal_crossing_pocket_camp"><img alt="" height="122" src="https://images.nintendolife.com/games/mobile/animal_crossing_pocket_camp/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/mobile/animal_crossing_pocket_camp"><span class="title accent-hover">Animal Crossing: Pocket Camp</span> <span class="subtitle">Mobile</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/mxgp_3" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/mxgp_3"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/mxgp_3/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/mxgp_3"><span class="title accent-hover">MXGP 3</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/superbeat_xonic" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/superbeat_xonic"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/superbeat_xonic/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/superbeat_xonic"><span class="title accent-hover">Superbeat: Xonic</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lumo" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lumo"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lumo/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lumo"><span class="title accent-hover">Lumo</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/3ds/pokemon_ultra_sun_and_ultra_moon" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><img alt="" height="122" src="https://images.nintendolife.com/games/3ds/pokemon_ultra_sun_and_ultra_moon/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><span class="title accent-hover">Pokémon Ultra Sun and Ultra Moon</span> <span class="subtitle">3DS</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/batman_-_the_telltale_series" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/batman_-_the_telltale_series"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/batman_-_the_telltale_series/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/batman_-_the_telltale_series"><span class="title accent-hover">Batman - The Telltale Series</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/ittle_dew_2plus" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/ittle_dew_2plus"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/ittle_dew_2plus/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/ittle_dew_2plus"><span class="title accent-hover">Ittle Dew 2+</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lego_marvel_super_heroes_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lego_marvel_super_heroes_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lego_marvel_super_heroes_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lego_marvel_super_heroes_2"><span class="title accent-hover">LEGO Marvel Super Heroes 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/rocket_league" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/rocket_league"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/rocket_league/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/rocket_league"><span class="title accent-hover">Rocket League</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/doom" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/doom"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/doom/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/doom"><span class="title accent-hover">DOOM</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/sonic_forces" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/sonic_forces"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/sonic_forces/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/sonic_forces"><span class="title accent-hover">Sonic Forces</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/super_mario_odyssey" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/super_mario_odyssey"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/super_mario_odyssey/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/super_mario_odyssey"><span class="title accent-hover">Super Mario Odyssey</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><span class="title accent-hover">Nights of Azure 2: Bride of the New Moon</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/poi_explorer_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/poi_explorer_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/poi_explorer_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/poi_explorer_edition"><span class="title accent-hover">Poi: Explorer Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/fire_emblem_warriors" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/fire_emblem_warriors"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fire_emblem_warriors/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fire_emblem_warriors"><span class="title accent-hover">Fire Emblem Warriors</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/88_heroes_98_heroes_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/88_heroes_98_heroes_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/88_heroes_98_heroes_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/88_heroes_98_heroes_edition"><span class="title accent-hover">88 Heroes: 98 Heroes Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/tiny_barbarian_dx" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/tiny_barbarian_dx"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/tiny_barbarian_dx/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/tiny_barbarian_dx"><span class="title accent-hover">Tiny Barbarian DX</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/oxenfree" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/oxenfree"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/oxenfree/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/oxenfree"><span class="title accent-hover">Oxenfree</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/fifa_18" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/fifa_18"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fifa_18/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fifa_18"><span class="title accent-hover">FIFA 18</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><span class="title accent-hover">One Piece Unlimited World Red - Deluxe Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/golf_story" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/golf_story"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/golf_story/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/golf_story"><span class="title accent-hover">Golf Story</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/sine_mora_ex" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/sine_mora_ex"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/sine_mora_ex/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/sine_mora_ex"><span class="title accent-hover">Sine Mora EX</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# ...
# <p class="heading"><a class="accent" href="news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo"><abbr title='Reggie Encouraged Nintendo To Embrace "What The Brand Stood For" By Sticking With Its Iconic Logo'>Reggie Encouraged Nintendo To Embrace "What The Brand Sto...</abbr></a></p>
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-26T06:55:00+00:00"><span>17 hours ago</span></time></p>
# </div></li><li><div class="item"><p class="image"><a href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far"><img alt="Guide: Nintendo Switch Pro: Everything We Know So Far" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
# <p class="heading"><a class="accent" href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far">Guide: Nintendo Switch Pro: Everything We Know So Far</a></p>
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-23T06:00:00+00:00"><span>4 days ago</span></time></p>
# </div></li></ul><p class="more"><a class="accent-hover" href="news">Show More <span class="icon icon-caret-down"></span></a></p>
# </section><nav class="social"><p class="text">Join <strong>913,836</strong> people following <strong>Nintendo Life</strong>:</p>
# <ul><li class="first"><a class="ui-social-feed" data-username="latest" href="https://www.nintendolife.com/feeds/latest" rel="external" title="Subscribe to our RSS Feed"><span class="icon icon-feed"></span> <span class="label">RSS Feed</span></a></li><li><a class="ui-social-twitter" data-username="nintendolife" href="https://twitter.com/nintendolife" rel="external" title="Nintendo Life on Twitter"><span class="icon icon-twitter"></span> <span class="label">Twitter</span></a></li><li><a class="ui-social-facebook" data-username="nintendolife" href="https://www.facebook.com/nintendolife" rel="external" title="Nintendo Life on Facebook"><span class="icon icon-facebook"></span> <span class="label">Facebook</span></a></li><li><a class="ui-social-youtube" data-username="nintendolife" href="https://www.youtube.com/nintendolife" rel="external" title="Nintendo Life on YouTube"><span class="icon icon-youtube"></span> <span class="label">YouTube</span></a></li><li><a class="ui-social-instagram" data-username="nintendolife" href="https://www.instagram.com/nintendolife/" rel="external" title="Nintendo Life on Instagram"><span class="icon icon-instagram"></span> <span class="label">Instagram</span></a></li><li class="last"><a class="ui-social-deviantart" data-username="nintendolife" href="https://www.deviantart.com/nintendolife" rel="external" title="Nintendo Life on DeviantArt"><span class="icon icon-deviantart"></span> <span class="label">DeviantArt</span></a></li></ul>
# </nav><p class="copyright">© 2020 <a href="https://nlife.com" rel="external">Nlife Media</a>, partner of <a href="https://www.gamer-network.net" rel="external">Gamer Network</a>. Hosted by <a href="https://www.44bytes.net/">44 Bytes</a>.</p>
# <ul class="list friends"><li class="first">Friends:</li><li><a href="https://nintendonews.com" rel="external" title="Nintendo News - All the latest Nintendo News from across the web.">Nintendo News</a></li><li><a href="https://www.pushsquare.com" rel="external" title="Push Square - covering everything PlayStation including PS Vita &amp; PS3 news and reviews.">Push Square</a></li><li><a href="https://www.eurogamer.net" rel="external" title="European coverage of the world of gaming - the mighty Eurogamer.net">Eurogamer.net</a></li><li><a href="https://www.usgamer.net" rel="external" title="US coverage of the world of gaming - it's USgamer">USgamer</a></li><li><a href="https://www.videogameschronicle.com" rel="external" title="The latest news from Video Games Chronicle">VGC</a></li><li><a href="https://www.rockpapershotgun.com" rel="external" title="Specialist PC gaming blog - Rock, Paper, Shotgun">Rock, Paper, Shotgun</a></li><li><a href="https://www.vg247.com" rel="external" title="Up to the minute news coverage for all formats - VG24/7">VG247</a></li><li class="last"><a href="https://www.gamesindustry.biz" rel="external" title="Stay on the pulse with industry news with the #1 resource - GamesIndustry.biz">GamesIndustry.biz</a></li></ul>
# </div></footer><footer id="gutter"><div class="inset">
# <form accept-charset="UTF-8" action="https://www.nintendolife.com/api/1.0/newsletter" enctype="multipart/form-data" id="ui-join-newsletter" method="post">
# <div><input id="csrf" name="_csrf" type="hidden" value="QZZ5R4AuiaX/1COjW3ZGWyF2gzMjsLHA/ta0S7V/OUFxD6MmHq3zKae1l5cpWKL1Ht8wd+HV8cbSRpsR3YCkqg=="/></div><input id="source" name="source" type="hidden" value="website"/><input id="format" name="format" type="hidden" value="flash"/><input id="campaign" name="campaign" type="hidden" value="gutter"/><div class="fm-field fm-field-all-the-latest-nintendo-goodness-straight-to-your-inbox">
# <label class="fm-field-name" for="email">All the latest Nintendo goodness straight to your inbox</label>
# <div class="fm-options">
# <input class="textbox" id="email" name="email" placeholder="Email Address" type="email" value=""/>
# </div>
# </div>
# <div class="fm-footer">
# <input class="button accent-bg-hover" id="submit" name="submit" type="submit" value="Join"/> <input id="humanoid" name="humanoid" type="hidden" value=""/>
# </div>
# </form>
# </div></footer><div id="amzn-assoc-ad-c814957b-9ca0-409b-a76c-79bd6726dd3f"></div><script async="" src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=c814957b-9ca0-409b-a76c-79bd6726dd3f"></script>
# <!-- cache: html/htmlTemplate:nintendolife.com/nintendolife.com.ssl/submenu @ 2020-01-26T20:40:39+00:00 --><script> var dgpSubmenus = "<div class=\"submenu\" id=\"submenu-topics\"><div class=\"inset\">\n<ul class=\"submenu-list\"><li><a data-color=\"#DC0000\" class=\"ui-change-topic\" href=\"nintendo-switch\"><span class=\"label\">Nintendo Switch</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#FF7D00\" class=\"ui-change-topic\" href=\"switch-eshop\"><span class=\"label\">Switch eShop</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E4A71E\" class=\"ui-change-topic\" href=\"pokemon-go\"><span class=\"label\">Pok\u00e9mon GO</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E6001E\" class=\"ui-change-topic\" href=\"3ds\"><span class=\"label\">3DS</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#009DC8\" class=\"ui-change-topic\" href=\"wiiu\"><span class=\"label\">Wii U</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n<ul class=\"submenu-list\"><li><a data-color=\"#CC0000\" class=\"ui-change-topic\" href=\"retro\"><span class=\"label\">Retro</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E32AC6\" class=\"ui-change-topic\" href=\"esports\"><span class=\"label\">eSports</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#F90070\" class=\"ui-change-topic\" href=\"dsiware\"><span class=\"label\">DSiWare</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#12B5EA\" class=\"ui-change-topic\" href=\"wiiware\"><span class=\"label\">WiiWare</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E54C76\" class=\"ui-change-topic\" href=\"cosplay\"><span class=\"label\">Cosplay</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n<ul class=\"submenu-list\"><li><a data-color=\"#F2A800\" class=\"ui-change-topic\" href=\"e3\"><span class=\"label\">E3</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#34BEEC\" class=\"ui-change-topic\" href=\"vc\"><span class=\"label\">Wii Virtual Console</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#18AA59\" class=\"ui-change-topic\" href=\"streetpass\"><span class=\"label\">StreetPass</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#EB599B\" class=\"ui-change-topic\" href=\"princess-peach\"><span class=\"label\">Princess Peach</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#6D66C8\" class=\"ui-change-topic\" href=\"fire-emblem\"><span class=\"label\">Fire Emblem</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n<ul class=\"submenu-list\"><li><a data-color=\"#2C53B2\" class=\"ui-change-topic\" href=\"star-fox\"><span class=\"label\">Star Fox</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#1EB7E4\" class=\"ui-change-topic\" href=\"samus\"><span class=\"label\">Samus Aran</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#7744DC\" class=\"ui-change-topic\" href=\"gamecube\"><span class=\"label\">GameCube</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#C800DC\" class=\"ui-change-topic\" href=\"splatoon\"><span class=\"label\">Splatoon</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a href=\"topics\"><span class=\"label\">+ More</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n</div></div>\n<div class=\"submenu\" id=\"submenu-news\"><div class=\"inset\">\n<ul class=\"submenu-list\"><li><a href=\"news\">Latest News <span class=\"icon icon-angle-right\"></span></a></li><li><a href=\"news/2020/week-04\">This Week <span class=\"icon icon-angle-right\"></span></a></li><li><a href=\"news/2020/week-03\">Last Week <span class=\"icon icon-angle-right\"></span ...
# <script type="text/javascript">
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "8518622" });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript>
# <img alt="" src="//b.scorecardresearch.com/p?c1=2&amp;c2=8518622&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <script>( function () {
# 	var _sp_=function(n){function t(e){if(o[e])return o[e].exports;var r=o[e]={i:e,l:!1,exports:{}};return n[e].call(r.exports,r,r.exports,t),r.l=!0,r.exports}var o={};return t.m=n,t.c=o,t.i=function(n){return n},t.d=function(n,o,e){t.o(n,o)||Object.defineProperty(n,o,{configurable:!1,enumerable:!0,get:e})},t.n=function(n){var o=n&&n.__esModule?function(){return n["default"]}:function(){return n};return t.d(o,"a",o),o},t.o=function(n,t){return Object.prototype.hasOwnProperty.call(n,t)},t.p="",t(t.s=2)}([function(n,t){function o(n,t){e&&console[n].apply(console,["[bootstrap]"].concat(Array.prototype.slice.call(t)))}var e=!1;n.exports={debug:function(){o("debug",arguments)},info:function(){o("info",arguments)},time:function(){o("time",arguments)},warn:function(){o("warn",arguments)},error:function(){o("error",arguments)},useDefaults:function(){e=!0},DEBUG:1}},function(n,t,o){"use strict";function e(){R||(R=!0,D=b.config=b.config||{},s(),F=D.bootstrap&&D.bootstrap.contentControlCallback||D.content_control_callback,q=D.accountId||D.account_id||D.client_id||window.sp_cid,N=D.beacon&&D.beacon.contentControlEndpoint||D.content_control_beacon_endpoint||v.a,D.debug_level&&"OFF"!==D.debug_level.toString().toUpperCase()||D.debug&&D.debug.level&&"OFF"!==D.debug.level.toString().toUpperCase()?j=!0:window.location.search&&null!=window.location.search.match(/_sp_debug_level=(?!off|OFF)/)&&(j=!0),j&&m.useDefaults({defaultLevel:m.DEBUG}))}function r(n,t,e){function r(o,e){var r=new Image;r.src="//"+N+"/cct?v="+encodeURIComponent(v.b)+"&ct="+h+"&cid="+encodeURIComponent(q)+"&l="+encodeURIComponent(n.toString())+"&rc="+encodeURIComponent(t)+"&d0="+encodeURIComponent(i)+(o?"&d1="+encodeURIComponent(o):"")+(null==e?"":"&d2="+encodeURIComponent(e)),g.info("sending beacon: "+r.src),c&&c()}var i=arguments.length>3&&void 0!==arguments[3]?arguments[3]:"",a=arguments[4],c=arguments[5];if(a){var d=e.lastIndexOf("."),u=e.lastIndexOf("/"),s=-1===d||u>d?e+".png":e.substring(0,d)+".png",l=new Image;l.addEventListener("load",function(){r("1",s)}),l.addEventListener("error",function(){o.i(f.a)(s,function(n,t,o){r("0",s+"::"+o)})}),l.src=s}else r()}function i(n,t,o,e){var r=arguments.length>4&&void 0!==arguments[4]?arguments[4]:{},a=arguments.length>5&&void 0!==arguments[5]&&arguments[5],c=function(){i(n,t,o,e,r,!0)};n(t,a?o:c,e,r)}function a(n,t,o,e){function r(o,r){t(o,n,r,e.enableImageLoad)}function i(t,r){o(t,n,r,e.enableImageLoad),e.onError&&e.onError(r)}var a=document.createElement("script");a.src=n,a.onload=function(){e.onLoad&&e.onLoad()},a.onerror=function(){function t(n){return o.indexOf(n)>-1}var o=(navigator.userAgent||navigator.vendor||window.opera).toLowerCase();t("mobi")||t("ipad")||t("android")||t("iphone")?i(L):t("exabot")?i(O):t("bingbot")||t("bingpreview")?i(k):t("googlebot")||t("adsbot-google")||t("mediapartners-google")?i(C):t("googleweblight")?i(E):window.location.host===w?i(x):t("msie 10")||t("msie 9")||t("msie 8")?i(I):c(n,r,i)},document.head.appendChild(a)}function c(n,t,e){o.i(f.a)(n,function(o,r,i,a){(o||r?t:e)(a,n+"::"+i)})}function d(n,t,o,e){if(S)return void u(U+"::"+n,o);r(y,n,t,o,e,function(){if(F){if(j){g.error("bootstrap locking",y,n,t,o,e);debugger}setTimeout(function(){F()},250)}})}function u(n,t,o,e){r(_,n,t,o,e)}function s(){b._networkListenerData||(b._networkListenerData=o.i(p.a)())}function l(n,t){e(),g.info("bootstrap called with",n,t),i(a,n,d,u,t)}Object.defineProperty(t,"__esModule",{value:!0});var f=o(4),p=o(5),v=o(3),g=o(0),m=void 0;m=o(0);var w=["w","e","b","c","a","c","h","e",".","g","o","o","g","l","e","u","s","e","r","c","o","n","t","e","n","t",".","c","o","m"].join(""),b=window._sp_||{},h=1,_=0,y=1,L="m",C="g",x="gw",E="gl",I="i",k="b",O="e",U="n",R=!1,S=!1,j=!1,D=void 0,F=void 0,q=void 0,N=void 0;window.addEventListener("beforeunload",function(){S=!0}),window._sp_=b,b.setupNetworkListeners=s,b.bootstrap=l,window.spBootstrap=l,t["default"]=b},function(n,t,o){o(0);n.exports=o(1)["default"]},function(n,t,o){"use stri ...
# 	//# sourceMappingURL=https://s3.amazonaws.com/d3jlsadfjkuern/2.0.1098/Ym9vdHN0cmFwLmpz.map
# 	window._sp_ =  window._sp_ || {};
# 	window._sp_.config =  window._sp_.config || {};
# 	window._sp_.config.account_id = 347;
#
# 	// ADD SUBDOMAIN HERE!
# 	window._sp_.config.mms_domain = 'sp.nintendolife.com';
# 	window._sp_.config.fsm_endpoint = "//fs.nintendolife.com";
# 	window._sp_.config.enable_fsm_detection = true;
# 	window._sp_.config.enable_fsm_network_detection = true;
#
# 	window._sp_.mms =  window._sp_.mms || {};
# 	window._sp_.mms.cmd =  window._sp_.mms.cmd || [];
# 	window._sp_.config.mms_client_data_callback =  function (o) {
# 		var _sp_msg_id = parseInt(o.info.msg_id);
# 		var _sp_cookie_val = "";
# 		if(o.d.abp==true && _sp_msg_id>0) {
# 			Cookies.set("sp", "sp_message_seen", { expires: 30 });
# 		}
# 	};
#
# 	window._sp_.mms.cmd.push( function () {
# 		// If user logged-in, do this...
# 		if (dgpConfig && dgpConfig["user"].user !== false) {
# 			window._sp_.mms.setTargeting("logged-in","true");
# 			// console.log('user');
# 		}
# 		else { // If user logged-out, do this...
# 			window._sp_.mms.setTargeting("logged-in","false");
# 			// console.log('guest');
# 		}
# 	});
#
# 	window._sp_.mms.cmd.push( function () {
# 		window._sp_.mms.startMsg();
# 	});
#
# 	// ADD PATH TO MSG JS FILE HERE!
# 	window._sp_.bootstrap('https://static.nintendolife.com/javascript/gn/sourcepoint.js');
#
# })();</script></body>
# </html>>

# %%
#Checking out the title
print(soup.title)
# Out:
# <title>link3710 - Games Collection - Nintendo Life</title>

# %%
#Checking out body
print(soup.body)
# Out:
# <body class="with-hero with-sidebar site-nintendolife device-desktop" data-subject="users/58197">
# <div id="fb-root"></div>
# <div class="template" id="template">
# <div class="header-wrap accent-bg">
# <header class="header" id="header">
# <nav class="menubar">
# <div class="headerbar"><ul id="toolbar">
# <li class="ui-button"><a class="ui-toggle-overlay" data-overlay="sidebar" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-bars"></span><span class="label">Menu</span></a></li>
# <li class="ui-button"><a class="ui-toggle-search" href="search" rel="nofollow"><span class="icon icon-search"></span><span class="label">Search</span></a>
# </li>
# </ul>
# <ul id="controlbar"><li class="ui-button"><a class="ui-share-page optional" href="share" rel="nofollow" title="Share This Page"><span class="icon icon-share"></span> <span class="label">Share</span></a><ul><li><a class="ui-share-page whatsapp" data-service="whatsapp" href="#" rel="nofollow" title="Share this page on WhatsApp"><span class="icon icon-whatsapp"></span></a></li><li><a class="ui-share-page messenger for-mobile" data-service="fbmessenger" href="#" rel="nofollow" title="Share this page on Facebook Messenger"><span class="icon icon-messenger"></span></a></li><li><a class="ui-share-page facebook" data-service="facebook" href="#" rel="nofollow" title="Share this page on Facebook"><span class="icon icon-facebook"></span></a></li><li><a class="ui-share-page twitter" data-service="twitter" href="#" rel="nofollow" title="Share this page on Twitter"><span class="icon icon-twitter"></span></a></li><li><a class="ui-share-page skype" data-service="skype" href="#" rel="nofollow" title="Share this page on Skype"><span class="icon icon-skype"></span></a></li><li><a class="ui-share-page reddit for-desktop" data-service="reddit" href="#" rel="nofollow" title="Share this page on reddit"><span class="icon icon-reddit"></span></a></li></ul></li><li class="ui-toggle-overlay ui-userinfo" data-overlay="userbar"><p class="avatar"><a href="login" rel="nofollow"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></a></p><p class="username optional">Guest</p><p class="subtitle optional"><a href="login" rel="nofollow">Login</a> or <a href="register" rel="nofollow">Sign Up</a></p></li></ul><p class="site-title"><a href="https://www.nintendolife.com/"><img alt="Nintendo Life" src="https://images.nintendolife.com/site/logo.svg?v=2&amp;colour=e60012" width="265"/></a></p>
# </div><form action="search" id="quick-search" method="get">
# <div class="controls"><label>Keywords</label> <input autocomplete="off" class="query textbox" id="query" name="q" placeholder="Search..." type="text"/> <input class="button" name="submit" type="submit" value="Go"/></div>
# </form>
# <div id="quick-search-results"><div id="search-results"></div></div><!-- cache: html:nintendolife.com/nintendolife.com.ssl/menu @ 2020-01-27T00:40:25+00:00 --><div class="ui-menus">
# <div class="accent-bg">
# <div class="accent-wrap">
# <div class="inset">
# <ul id="menu">
# <li><a class="main-menu-item" href="https://www.nintendolife.com/" title="Home"><span class="icon icon-wiiu-home"></span> <span class="label">Home</span></a></li><li class="has-submenu"><a class="main-menu-item no-icon" data-name="topics" href="topics"><span class="label ui-topic-title">Topics</span> <span class="icon icon-caret-down"></span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="news" href="/news"><span class="icon icon-news optional"></span> <span class="label">News</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="reviews" href="/reviews"><span class="icon icon-reviews optional"></span> <span class="label">Reviews</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="features" href="/features"><span class="icon icon-features optional"></span> <span class="label">Features</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="games" href="/games/browse"><span class="icon icon-books optional"></span> <span class="label">Games</span></a></li><li><a class="main-menu-item" data-name="guides" href="/guides"><span class="icon icon-map optional"></span> <span class="label">Guides</span></a></li><li><a class="main-menu-item external" href="https://www.youtube.com/nintendolife"><span class="icon icon-videos optional"></span> <span class="label">Videos</span></a></li><li class="has-submenu"><a class="main-menu-item" data-name="forums" href="/forums"><span class="icon icon-comments optional"></span> <span class="label">Forums</span></a></li></ul>
# </div>
# </div>
# </div>
# <div id="submenus"></div></div></nav><nav class="ui-overlays"><section class="ui-overlay" id="userbar"><div class="buffer"><p class="avatar"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></p><p><a class="username ui-user-profile" href="user/profile" rel="nofollow">Guest</a></p><p class="subtitle"><a href="login" rel="nofollow">Login</a> or <a href="register" rel="nofollow">Sign Up</a></p></div><div class="scroll"><div class="body"><ul><li><a class="ui-user-notifications" href="user/notifications" rel="nofollow" title="Number of unread notifications"><span class="icon icon-notification"></span> <span class="label">Notifications</span> <span class="counter accent-bg">0</span></a></li><li><a class="ui-user-games" href="user/games" rel="nofollow"><span class="icon icon-books"></span> <span class="label">Games Collection</span> <span class="icon icon-angle-right right"></span></a></li><li><a class="ui-user-profile" href="user/profile" rel="nofollow"><span class="icon icon-profile"></span> <span class="label">View Profile</span> <span class="icon icon-angle-right right"></span></a></li></ul><ul><li><a href="user" rel="nofollow"><span class="icon icon-settings"></span> <span class="label">Your Account</span> <span class="icon icon-angle-right right"></span></a></li><li><a href="logout" rel="nofollow"><span class="icon icon-logout"></span> <span class="label">Logout</span> <span class="icon icon-angle-right right"></span></a></li></ul></div></div></section><section class="ui-overlay" id="sidebar"><div class="buffer"></div><div class="scroll"><div class="body"><ul class="optional"><li><a href="https://www.nintendolife.com/"><span class="icon icon-wiiu-home"></span> <span class="label">Home</span> <span class="icon icon-angle-right right"></span></a></li></ul><ul class="ui-user-hubs"><li><a href="topics" rel="nofollow"><span class="icon icon-topic"></span> <span class="label">Choose Topics...</span> <span class="icon icon-angle-right right"></span></a></li></ul><ul class="ui-user-manage-hubs"><li><a href="topics" rel="nofollow"><span class="icon icon-settings"></span> <span class="label">Manage Topics</span> <span class="icon icon-angle-right right"></span></a></li></ul></div></div></section></nav><div class="flash"></div></header></div><div class="page" id="page"><div class="masthead inset"><div class="insert for-desktop"><div data-dfp-id="NL_LB_1" data-dfp-sizes="1280x250,1260x110,970x250,960x250,728x90" data-ghost-zone="31" id="r5e2e31b350ccb"></div>
# </div></div><div class="content-wrapper"><section class="hero"><div class="hero-wrap"><div class="background accent-bg no-artwork"></div><div class="accent-bg"><div class="inset"><div class="hero-title with-avatar"><p class="image accent-bg"><img alt="link3710" height="200" src="https://images.nintendolife.com/users/58197/200x200.jpg?v=1516306053" width="200"/></p>
# <h1 class="title"><a href="/users/link3710">link3710</a> </h1>
# <h2 class="heading">User</h2>
# </div><ul class="linkbar"><li class="first"><a href="/users/link3710">Profile</a></li><li><a class="current" href="/users/link3710/games">Games</a></li><li><a href="/users/link3710/comments">Comments</a></li><li><a href="/users/link3710/topics">Discussions</a></li><li class="last"><a href="login">Posts</a></li></ul>
# </div></div></div></section><div class="inset"><div id="body"><div class="content" id="content">
# <section class="container type-user-games with-filters" data-default-style="tile" data-limit="60" data-offset="0" data-param="id=games-collection&amp;sort=date&amp;status=own&amp;type=user-games&amp;user=users%2f58197&amp;view=games" data-style="tile" data-styles="tile" id="listing-games-collection"><nav class="ui-listing-filters"><form action="users/link3710/games" method="get"><h2 class="heading">Filter <span class="icon icon-caret-down"></span></h2>
# <div class="ui-listing-filters-body"><div class="ui-listing-filter ui-listing-filter-collapse"><input autocomplete="off" class="ui-filter-search" data-filter="title" name="title" placeholder="Search..." type="text" value=""/></div><div class="ui-listing-filter"><h3 class="heading">Status<span class="icon icon-caret-down"></span></h3>
# <div class="ui-filter-options">
# <span class="fm-checkbox fm-checkbox-selected"><input checked="checked" class="radio" id="status-opt1" name="status[]" type="checkbox" value="own"> <label class="checkbox" for="status-opt1">Have <span class="count">189</span></label></input></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt2" name="status[]" type="checkbox" value="owned"/> <label class="checkbox" for="status-opt2">Owned <span class="count">2</span></label></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt3" name="status[]" type="checkbox" value="want"/> <label class="checkbox" for="status-opt3">Want <span class="count">103</span></label></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt4" name="status[]" type="checkbox" value="maybe"/> <label class="checkbox" for="status-opt4">Maybe <span class="count">124</span></label></span>
# <span class="fm-checkbox"><input class="radio" id="status-opt5" name="status[]" type="checkbox" value="not-interested"/> <label class="checkbox" for="status-opt5">Nope! <span class="count">86</span></label></span> </div></div><div class="ui-listing-filter ui-listing-filter-collapse"><h3 class="heading">Score<span class="icon icon-caret-left"></span></h3>
# <div class="ui-filter-options">
# <span class="fm-checkbox"><input class="radio" id="score-opt1" name="score[]" type="checkbox" value="10"/> <label class="checkbox" for="score-opt1">10/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt2" name="score[]" type="checkbox" value="9"/> <label class="checkbox" for="score-opt2">9/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt3" name="score[]" type="checkbox" value="8"/> <label class="checkbox" for="score-opt3">8/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt4" name="score[]" type="checkbox" value="7"/> <label class="checkbox" for="score-opt4">7/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt5" name="score[]" type="checkbox" value="6"/> <label class="checkbox" for="score-opt5">6/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt6" name="score[]" type="checkbox" value="5"/> <label class="checkbox" for="score-opt6">5/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt7" name="score[]" type="checkbox" value="4"/> <label class="checkbox" for="score-opt7">4/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt8" name="score[]" type="checkbox" value="3"/> <label class="checkbox" for="score-opt8">3/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt9" name="score[]" type="checkbox" value="2"/> <label class="checkbox" for="score-opt9">2/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt10" name="score[]" type="checkbox" value="1"/> <label class="checkbox" for="score-opt10">1/10</label></span>
# <span class="fm-checkbox"><input class="radio" id="score-opt11" name="score[]" type="checkbox" value="none"/> <label class="checkbox" for="score-opt11">No Score</label></span> </div></div><div class="ui-listing-filter ui-listing-filter-collapse"><h3 class="heading">System<span class="icon icon-caret-left"></span></h3>
# <div class="ui-filter-options">
# <span class="fm-checkbox"><input class="radio" id="system-opt1" name="system[]" type="checkbox" value="systems/3ds"/> <label class="checkbox" for="system-opt1">3DS (157)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt2" name="system[]" type="checkbox" value="systems/nintendo-switch"/> <label class="checkbox" for="system-opt2">Switch (156)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt3" name="system[]" type="checkbox" value="systems/switch-eshop"/> <label class="checkbox" for="system-opt3">Switch eShop (80)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt4" name="system[]" type="checkbox" value="systems/wiiu"/> <label class="checkbox" for="system-opt4">Wii U (38)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt5" name="system[]" type="checkbox" value="systems/gameboy"/> <label class="checkbox" for="system-opt5">GB (18)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt6" name="system[]" type="checkbox" value="systems/wii"/> <label class="checkbox" for="system-opt6">Wii (16)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt7" name="system[]" type="checkbox" value="systems/ds"/> <label class="checkbox" for="system-opt7">DS (10)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt8" name="system[]" type="checkbox" value="systems/new-3ds"/> <label class="checkbox" for="system-opt8">New 3DS (10)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt9" name="system[]" type="checkbox" value="systems/3ds-eshop"/> <label class="checkbox" for="system-opt9">3DS eShop (6)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt10" name="system[]" type="checkbox" value="systems/gamecube"/> <label class="checkbox" for="system-opt10">GCN (6)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt11" name="system[]" type="checkbox" value="systems/wiiu-eshop"/> <label class="checkbox" for="system-opt11">Wii U eShop (4)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt12" name="system[]" type="checkbox" value="systems/gbc"/> <label class="checkbox" for="system-opt12">GBC (2)</label></span>
# <span class="fm-checkbox"><input class="radio" id="system-opt13" name="system[]" type="checkbox" value="systems/mobile"/> <label class="checkbox" for="system-opt13">Mobile (1)</label></span> </div></div></div><noscript><input name="submit" type="submit" value="Search"/></noscript></form></nav><nav class="ui-views"><div class="ui-listing-toggles"><select class="select ui-listing-sorts" id="sort" name="sort">
# <option selected="selected" value="date">Release Date</option>
# <option value="added">Added</option>
# <option value="score">User Score</option>
# <option value="rating">Rating</option>
# <option value="title">Title</option>
# </select> <select class="select ui-listing-styles" id="style" name="style">
# <option selected="selected" value="tile">Tile</option>
# </select> </div><ul class="panels"><li class="first last"><a class="selected accent accent-border" data-view="games" href="users/link3710/games#games">Games</a></li></ul>
# </nav><div class="ui-listing-body"><ul class="items cols-3 style-tile"><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/daemon_x_machina" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/daemon_x_machina"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/daemon_x_machina/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/daemon_x_machina"><span class="title accent-hover">Daemon X Machina</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/spyro_reignited_trilogy" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/spyro_reignited_trilogy"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/spyro_reignited_trilogy/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/spyro_reignited_trilogy"><span class="title accent-hover">Spyro Reignited Trilogy</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/gato_roboto" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/gato_roboto"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/gato_roboto/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/gato_roboto"><span class="title accent-hover">Gato Roboto</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/deltarune_chapter_1" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/deltarune_chapter_1"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/deltarune_chapter_1/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/deltarune_chapter_1"><span class="title accent-hover">DELTARUNE Chapter 1</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/super_smash_bros_ultimate" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/super_smash_bros_ultimate"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/super_smash_bros_ultimate/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/super_smash_bros_ultimate"><span class="title accent-hover">Super Smash Bros. Ultimate</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/katamari_damacy_reroll" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/katamari_damacy_reroll"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/katamari_damacy_reroll/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/katamari_damacy_reroll"><span class="title accent-hover">Katamari Damacy REROLL</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/horizon_chase_turbo" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/horizon_chase_turbo"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/horizon_chase_turbo/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/horizon_chase_turbo"><span class="title accent-hover">Horizon Chase Turbo</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/dragon_ball_fighterz" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/dragon_ball_fighterz"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/dragon_ball_fighterz/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/dragon_ball_fighterz"><span class="title accent-hover">Dragon Ball FighterZ</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/undertale" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/undertale"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/undertale/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/undertale"><span class="title accent-hover">Undertale</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/okami_hd" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/okami_hd"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/okami_hd/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/okami_hd"><span class="title accent-hover">Okami HD</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/yokus_island_express" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/yokus_island_express"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/yokus_island_express/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/yokus_island_express"><span class="title accent-hover">Yoku's Island Express</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/bayonetta_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/bayonetta_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/bayonetta_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/bayonetta_2"><span class="title accent-hover">Bayonetta 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/bayonetta" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/bayonetta"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/bayonetta/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/bayonetta"><span class="title accent-hover">Bayonetta</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lost_sphear" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lost_sphear"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lost_sphear/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lost_sphear"><span class="title accent-hover">Lost Sphear</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/xenoblade_chronicles_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/xenoblade_chronicles_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/xenoblade_chronicles_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/xenoblade_chronicles_2"><span class="title accent-hover">Xenoblade Chronicles 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/mobile/animal_crossing_pocket_camp" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/mobile/animal_crossing_pocket_camp"><img alt="" height="122" src="https://images.nintendolife.com/games/mobile/animal_crossing_pocket_camp/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/mobile/animal_crossing_pocket_camp"><span class="title accent-hover">Animal Crossing: Pocket Camp</span> <span class="subtitle">Mobile</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/mxgp_3" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/mxgp_3"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/mxgp_3/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/mxgp_3"><span class="title accent-hover">MXGP 3</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/superbeat_xonic" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/superbeat_xonic"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/superbeat_xonic/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/superbeat_xonic"><span class="title accent-hover">Superbeat: Xonic</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lumo" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lumo"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lumo/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lumo"><span class="title accent-hover">Lumo</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/3ds/pokemon_ultra_sun_and_ultra_moon" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><img alt="" height="122" src="https://images.nintendolife.com/games/3ds/pokemon_ultra_sun_and_ultra_moon/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><span class="title accent-hover">Pokémon Ultra Sun and Ultra Moon</span> <span class="subtitle">3DS</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/batman_-_the_telltale_series" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/batman_-_the_telltale_series"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/batman_-_the_telltale_series/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/batman_-_the_telltale_series"><span class="title accent-hover">Batman - The Telltale Series</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/ittle_dew_2plus" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/ittle_dew_2plus"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/ittle_dew_2plus/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/ittle_dew_2plus"><span class="title accent-hover">Ittle Dew 2+</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lego_marvel_super_heroes_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lego_marvel_super_heroes_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lego_marvel_super_heroes_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lego_marvel_super_heroes_2"><span class="title accent-hover">LEGO Marvel Super Heroes 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/rocket_league" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/rocket_league"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/rocket_league/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/rocket_league"><span class="title accent-hover">Rocket League</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/doom" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/doom"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/doom/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/doom"><span class="title accent-hover">DOOM</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/sonic_forces" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/sonic_forces"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/sonic_forces/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/sonic_forces"><span class="title accent-hover">Sonic Forces</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/super_mario_odyssey" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/super_mario_odyssey"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/super_mario_odyssey/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/super_mario_odyssey"><span class="title accent-hover">Super Mario Odyssey</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><span class="title accent-hover">Nights of Azure 2: Bride of the New Moon</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/poi_explorer_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/poi_explorer_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/poi_explorer_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/poi_explorer_edition"><span class="title accent-hover">Poi: Explorer Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/fire_emblem_warriors" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/fire_emblem_warriors"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fire_emblem_warriors/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fire_emblem_warriors"><span class="title accent-hover">Fire Emblem Warriors</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/88_heroes_98_heroes_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/88_heroes_98_heroes_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/88_heroes_98_heroes_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/88_heroes_98_heroes_edition"><span class="title accent-hover">88 Heroes: 98 Heroes Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/tiny_barbarian_dx" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/tiny_barbarian_dx"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/tiny_barbarian_dx/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/tiny_barbarian_dx"><span class="title accent-hover">Tiny Barbarian DX</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/oxenfree" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/oxenfree"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/oxenfree/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/oxenfree"><span class="title accent-hover">Oxenfree</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/fifa_18" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/fifa_18"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fifa_18/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fifa_18"><span class="title accent-hover">FIFA 18</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><span class="title accent-hover">One Piece Unlimited World Red - Deluxe Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/golf_story" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/golf_story"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/golf_story/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/golf_story"><span class="title accent-hover">Golf Story</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/sine_mora_ex" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/sine_mora_ex"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/sine_mora_ex/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/sine_mora_ex"><span class="title accent-hover">Sine Mora EX</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/dragon_ball_xenoverse_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/dragon_ball_xenoverse_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/dragon_ball_xenoverse_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/dragon_ball_xenoverse_2"><span class="title accent-hover">Dragon Ball Xenoverse 2</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/steamworld_dig_2" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/steamworld_dig_2"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/steamworld_dig_2/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/steamworld_dig_2"><span class="title accent-hover">SteamWorld Dig 2</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/soldam_drop_connect_erase" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/soldam_drop_connect_erase"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/soldam_drop_connect_erase/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/soldam_drop_connect_erase"><span class="title accent-hover">Soldam: Drop, Connect, Erase</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/3ds/metroid_samus_returns" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/3ds/metroid_samus_returns"><img alt="" height="122" src="https://images.nintendolife.com/games/3ds/metroid_samus_returns/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/3ds/metroid_samus_returns"><span class="title accent-hover">Metroid: Samus Returns</span> <span class="subtitle">3DS</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/rayman_legends_definitive_edition" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/rayman_legends_definitive_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/rayman_legends_definitive_edition/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/rayman_legends_definitive_edition"><span class="title accent-hover">Rayman Legends: Definitive Edition</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/switch-eshop/bridge" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/switch-eshop/bridge"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/bridge/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/switch-eshop/bridge"><span class="title accent-hover">The Bridge</span> <span class="subtitle">Switch eShop</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# </div></div></div></li><li class="item item-content item-game" data-game-status="own" data-subject="games/nintendo-switch/lego_worlds" data-type="game"><div class="item-wrap"><div class="image"><a class="img" href="games/nintendo-switch/lego_worlds"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lego_worlds/220x122.jpg" width="220"/></a></div><div class="info"><div class="info-wrap"><p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lego_worlds"><span class="title accent-hover">LEGO Worlds</span> <span class="subtitle">Switch</span></a></p>
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
# ...
# <p class="heading"><a class="accent" href="news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo"><abbr title='Reggie Encouraged Nintendo To Embrace "What The Brand Stood For" By Sticking With Its Iconic Logo'>Reggie Encouraged Nintendo To Embrace "What The Brand Sto...</abbr></a></p>
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-26T06:55:00+00:00"><span>17 hours ago</span></time></p>
# </div></li><li><div class="item"><p class="image"><a href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far"><img alt="Guide: Nintendo Switch Pro: Everything We Know So Far" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
# <p class="heading"><a class="accent" href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far">Guide: Nintendo Switch Pro: Everything We Know So Far</a></p>
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-23T06:00:00+00:00"><span>4 days ago</span></time></p>
# </div></li></ul><p class="more"><a class="accent-hover" href="news">Show More <span class="icon icon-caret-down"></span></a></p>
# </section><nav class="social"><p class="text">Join <strong>913,836</strong> people following <strong>Nintendo Life</strong>:</p>
# <ul><li class="first"><a class="ui-social-feed" data-username="latest" href="https://www.nintendolife.com/feeds/latest" rel="external" title="Subscribe to our RSS Feed"><span class="icon icon-feed"></span> <span class="label">RSS Feed</span></a></li><li><a class="ui-social-twitter" data-username="nintendolife" href="https://twitter.com/nintendolife" rel="external" title="Nintendo Life on Twitter"><span class="icon icon-twitter"></span> <span class="label">Twitter</span></a></li><li><a class="ui-social-facebook" data-username="nintendolife" href="https://www.facebook.com/nintendolife" rel="external" title="Nintendo Life on Facebook"><span class="icon icon-facebook"></span> <span class="label">Facebook</span></a></li><li><a class="ui-social-youtube" data-username="nintendolife" href="https://www.youtube.com/nintendolife" rel="external" title="Nintendo Life on YouTube"><span class="icon icon-youtube"></span> <span class="label">YouTube</span></a></li><li><a class="ui-social-instagram" data-username="nintendolife" href="https://www.instagram.com/nintendolife/" rel="external" title="Nintendo Life on Instagram"><span class="icon icon-instagram"></span> <span class="label">Instagram</span></a></li><li class="last"><a class="ui-social-deviantart" data-username="nintendolife" href="https://www.deviantart.com/nintendolife" rel="external" title="Nintendo Life on DeviantArt"><span class="icon icon-deviantart"></span> <span class="label">DeviantArt</span></a></li></ul>
# </nav><p class="copyright">© 2020 <a href="https://nlife.com" rel="external">Nlife Media</a>, partner of <a href="https://www.gamer-network.net" rel="external">Gamer Network</a>. Hosted by <a href="https://www.44bytes.net/">44 Bytes</a>.</p>
# <ul class="list friends"><li class="first">Friends:</li><li><a href="https://nintendonews.com" rel="external" title="Nintendo News - All the latest Nintendo News from across the web.">Nintendo News</a></li><li><a href="https://www.pushsquare.com" rel="external" title="Push Square - covering everything PlayStation including PS Vita &amp; PS3 news and reviews.">Push Square</a></li><li><a href="https://www.eurogamer.net" rel="external" title="European coverage of the world of gaming - the mighty Eurogamer.net">Eurogamer.net</a></li><li><a href="https://www.usgamer.net" rel="external" title="US coverage of the world of gaming - it's USgamer">USgamer</a></li><li><a href="https://www.videogameschronicle.com" rel="external" title="The latest news from Video Games Chronicle">VGC</a></li><li><a href="https://www.rockpapershotgun.com" rel="external" title="Specialist PC gaming blog - Rock, Paper, Shotgun">Rock, Paper, Shotgun</a></li><li><a href="https://www.vg247.com" rel="external" title="Up to the minute news coverage for all formats - VG24/7">VG247</a></li><li class="last"><a href="https://www.gamesindustry.biz" rel="external" title="Stay on the pulse with industry news with the #1 resource - GamesIndustry.biz">GamesIndustry.biz</a></li></ul>
# </div></footer><footer id="gutter"><div class="inset">
# <form accept-charset="UTF-8" action="https://www.nintendolife.com/api/1.0/newsletter" enctype="multipart/form-data" id="ui-join-newsletter" method="post">
# <div><input id="csrf" name="_csrf" type="hidden" value="QZZ5R4AuiaX/1COjW3ZGWyF2gzMjsLHA/ta0S7V/OUFxD6MmHq3zKae1l5cpWKL1Ht8wd+HV8cbSRpsR3YCkqg=="/></div><input id="source" name="source" type="hidden" value="website"/><input id="format" name="format" type="hidden" value="flash"/><input id="campaign" name="campaign" type="hidden" value="gutter"/><div class="fm-field fm-field-all-the-latest-nintendo-goodness-straight-to-your-inbox">
# <label class="fm-field-name" for="email">All the latest Nintendo goodness straight to your inbox</label>
# <div class="fm-options">
# <input class="textbox" id="email" name="email" placeholder="Email Address" type="email" value=""/>
# </div>
# </div>
# <div class="fm-footer">
# <input class="button accent-bg-hover" id="submit" name="submit" type="submit" value="Join"/> <input id="humanoid" name="humanoid" type="hidden" value=""/>
# </div>
# </form>
# </div></footer><div id="amzn-assoc-ad-c814957b-9ca0-409b-a76c-79bd6726dd3f"></div><script async="" src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=c814957b-9ca0-409b-a76c-79bd6726dd3f"></script>
# <!-- cache: html/htmlTemplate:nintendolife.com/nintendolife.com.ssl/submenu @ 2020-01-26T20:40:39+00:00 --><script> var dgpSubmenus = "<div class=\"submenu\" id=\"submenu-topics\"><div class=\"inset\">\n<ul class=\"submenu-list\"><li><a data-color=\"#DC0000\" class=\"ui-change-topic\" href=\"nintendo-switch\"><span class=\"label\">Nintendo Switch</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#FF7D00\" class=\"ui-change-topic\" href=\"switch-eshop\"><span class=\"label\">Switch eShop</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E4A71E\" class=\"ui-change-topic\" href=\"pokemon-go\"><span class=\"label\">Pok\u00e9mon GO</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E6001E\" class=\"ui-change-topic\" href=\"3ds\"><span class=\"label\">3DS</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#009DC8\" class=\"ui-change-topic\" href=\"wiiu\"><span class=\"label\">Wii U</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n<ul class=\"submenu-list\"><li><a data-color=\"#CC0000\" class=\"ui-change-topic\" href=\"retro\"><span class=\"label\">Retro</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E32AC6\" class=\"ui-change-topic\" href=\"esports\"><span class=\"label\">eSports</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#F90070\" class=\"ui-change-topic\" href=\"dsiware\"><span class=\"label\">DSiWare</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#12B5EA\" class=\"ui-change-topic\" href=\"wiiware\"><span class=\"label\">WiiWare</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#E54C76\" class=\"ui-change-topic\" href=\"cosplay\"><span class=\"label\">Cosplay</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n<ul class=\"submenu-list\"><li><a data-color=\"#F2A800\" class=\"ui-change-topic\" href=\"e3\"><span class=\"label\">E3</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#34BEEC\" class=\"ui-change-topic\" href=\"vc\"><span class=\"label\">Wii Virtual Console</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#18AA59\" class=\"ui-change-topic\" href=\"streetpass\"><span class=\"label\">StreetPass</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#EB599B\" class=\"ui-change-topic\" href=\"princess-peach\"><span class=\"label\">Princess Peach</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#6D66C8\" class=\"ui-change-topic\" href=\"fire-emblem\"><span class=\"label\">Fire Emblem</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n<ul class=\"submenu-list\"><li><a data-color=\"#2C53B2\" class=\"ui-change-topic\" href=\"star-fox\"><span class=\"label\">Star Fox</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#1EB7E4\" class=\"ui-change-topic\" href=\"samus\"><span class=\"label\">Samus Aran</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#7744DC\" class=\"ui-change-topic\" href=\"gamecube\"><span class=\"label\">GameCube</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a data-color=\"#C800DC\" class=\"ui-change-topic\" href=\"splatoon\"><span class=\"label\">Splatoon</span> <span class=\"icon icon-angle-right\"></span></a></li><li><a href=\"topics\"><span class=\"label\">+ More</span> <span class=\"icon icon-angle-right\"></span></a></li></ul>\n</div></div>\n<div class=\"submenu\" id=\"submenu-news\"><div class=\"inset\">\n<ul class=\"submenu-list\"><li><a href=\"news\">Latest News <span class=\"icon icon-angle-right\"></span></a></li><li><a href=\"news/2020/week-04\">This Week <span class=\"icon icon-angle-right\"></span></a></li><li><a href=\"news/2020/week-03\">Last Week <span class=\"icon icon-angle-right\"></span ...
# <script type="text/javascript">
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "8518622" });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript>
# <img alt="" src="//b.scorecardresearch.com/p?c1=2&amp;c2=8518622&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <script>( function () {
# 	var _sp_=function(n){function t(e){if(o[e])return o[e].exports;var r=o[e]={i:e,l:!1,exports:{}};return n[e].call(r.exports,r,r.exports,t),r.l=!0,r.exports}var o={};return t.m=n,t.c=o,t.i=function(n){return n},t.d=function(n,o,e){t.o(n,o)||Object.defineProperty(n,o,{configurable:!1,enumerable:!0,get:e})},t.n=function(n){var o=n&&n.__esModule?function(){return n["default"]}:function(){return n};return t.d(o,"a",o),o},t.o=function(n,t){return Object.prototype.hasOwnProperty.call(n,t)},t.p="",t(t.s=2)}([function(n,t){function o(n,t){e&&console[n].apply(console,["[bootstrap]"].concat(Array.prototype.slice.call(t)))}var e=!1;n.exports={debug:function(){o("debug",arguments)},info:function(){o("info",arguments)},time:function(){o("time",arguments)},warn:function(){o("warn",arguments)},error:function(){o("error",arguments)},useDefaults:function(){e=!0},DEBUG:1}},function(n,t,o){"use strict";function e(){R||(R=!0,D=b.config=b.config||{},s(),F=D.bootstrap&&D.bootstrap.contentControlCallback||D.content_control_callback,q=D.accountId||D.account_id||D.client_id||window.sp_cid,N=D.beacon&&D.beacon.contentControlEndpoint||D.content_control_beacon_endpoint||v.a,D.debug_level&&"OFF"!==D.debug_level.toString().toUpperCase()||D.debug&&D.debug.level&&"OFF"!==D.debug.level.toString().toUpperCase()?j=!0:window.location.search&&null!=window.location.search.match(/_sp_debug_level=(?!off|OFF)/)&&(j=!0),j&&m.useDefaults({defaultLevel:m.DEBUG}))}function r(n,t,e){function r(o,e){var r=new Image;r.src="//"+N+"/cct?v="+encodeURIComponent(v.b)+"&ct="+h+"&cid="+encodeURIComponent(q)+"&l="+encodeURIComponent(n.toString())+"&rc="+encodeURIComponent(t)+"&d0="+encodeURIComponent(i)+(o?"&d1="+encodeURIComponent(o):"")+(null==e?"":"&d2="+encodeURIComponent(e)),g.info("sending beacon: "+r.src),c&&c()}var i=arguments.length>3&&void 0!==arguments[3]?arguments[3]:"",a=arguments[4],c=arguments[5];if(a){var d=e.lastIndexOf("."),u=e.lastIndexOf("/"),s=-1===d||u>d?e+".png":e.substring(0,d)+".png",l=new Image;l.addEventListener("load",function(){r("1",s)}),l.addEventListener("error",function(){o.i(f.a)(s,function(n,t,o){r("0",s+"::"+o)})}),l.src=s}else r()}function i(n,t,o,e){var r=arguments.length>4&&void 0!==arguments[4]?arguments[4]:{},a=arguments.length>5&&void 0!==arguments[5]&&arguments[5],c=function(){i(n,t,o,e,r,!0)};n(t,a?o:c,e,r)}function a(n,t,o,e){function r(o,r){t(o,n,r,e.enableImageLoad)}function i(t,r){o(t,n,r,e.enableImageLoad),e.onError&&e.onError(r)}var a=document.createElement("script");a.src=n,a.onload=function(){e.onLoad&&e.onLoad()},a.onerror=function(){function t(n){return o.indexOf(n)>-1}var o=(navigator.userAgent||navigator.vendor||window.opera).toLowerCase();t("mobi")||t("ipad")||t("android")||t("iphone")?i(L):t("exabot")?i(O):t("bingbot")||t("bingpreview")?i(k):t("googlebot")||t("adsbot-google")||t("mediapartners-google")?i(C):t("googleweblight")?i(E):window.location.host===w?i(x):t("msie 10")||t("msie 9")||t("msie 8")?i(I):c(n,r,i)},document.head.appendChild(a)}function c(n,t,e){o.i(f.a)(n,function(o,r,i,a){(o||r?t:e)(a,n+"::"+i)})}function d(n,t,o,e){if(S)return void u(U+"::"+n,o);r(y,n,t,o,e,function(){if(F){if(j){g.error("bootstrap locking",y,n,t,o,e);debugger}setTimeout(function(){F()},250)}})}function u(n,t,o,e){r(_,n,t,o,e)}function s(){b._networkListenerData||(b._networkListenerData=o.i(p.a)())}function l(n,t){e(),g.info("bootstrap called with",n,t),i(a,n,d,u,t)}Object.defineProperty(t,"__esModule",{value:!0});var f=o(4),p=o(5),v=o(3),g=o(0),m=void 0;m=o(0);var w=["w","e","b","c","a","c","h","e",".","g","o","o","g","l","e","u","s","e","r","c","o","n","t","e","n","t",".","c","o","m"].join(""),b=window._sp_||{},h=1,_=0,y=1,L="m",C="g",x="gw",E="gl",I="i",k="b",O="e",U="n",R=!1,S=!1,j=!1,D=void 0,F=void 0,q=void 0,N=void 0;window.addEventListener("beforeunload",function(){S=!0}),window._sp_=b,b.setupNetworkListeners=s,b.bootstrap=l,window.spBootstrap=l,t["default"]=b},function(n,t,o){o(0);n.exports=o(1)["default"]},function(n,t,o){"use stri ...
# 	//# sourceMappingURL=https://s3.amazonaws.com/d3jlsadfjkuern/2.0.1098/Ym9vdHN0cmFwLmpz.map
# 	window._sp_ =  window._sp_ || {};
# 	window._sp_.config =  window._sp_.config || {};
# 	window._sp_.config.account_id = 347;
#
# 	// ADD SUBDOMAIN HERE!
# 	window._sp_.config.mms_domain = 'sp.nintendolife.com';
# 	window._sp_.config.fsm_endpoint = "//fs.nintendolife.com";
# 	window._sp_.config.enable_fsm_detection = true;
# 	window._sp_.config.enable_fsm_network_detection = true;
#
# 	window._sp_.mms =  window._sp_.mms || {};
# 	window._sp_.mms.cmd =  window._sp_.mms.cmd || [];
# 	window._sp_.config.mms_client_data_callback =  function (o) {
# 		var _sp_msg_id = parseInt(o.info.msg_id);
# 		var _sp_cookie_val = "";
# 		if(o.d.abp==true && _sp_msg_id>0) {
# 			Cookies.set("sp", "sp_message_seen", { expires: 30 });
# 		}
# 	};
#
# 	window._sp_.mms.cmd.push( function () {
# 		// If user logged-in, do this...
# 		if (dgpConfig && dgpConfig["user"].user !== false) {
# 			window._sp_.mms.setTargeting("logged-in","true");
# 			// console.log('user');
# 		}
# 		else { // If user logged-out, do this...
# 			window._sp_.mms.setTargeting("logged-in","false");
# 			// console.log('guest');
# 		}
# 	});
#
# 	window._sp_.mms.cmd.push( function () {
# 		window._sp_.mms.startMsg();
# 	});
#
# 	// ADD PATH TO MSG JS FILE HERE!
# 	window._sp_.bootstrap('https://static.nintendolife.com/javascript/gn/sourcepoint.js');
#
# })();</script></body>

# %%
games = soup.findAll("p")

# %%
len(games)
# Out:
# 169

# %%
for i in range(len(games)):
    print(games[i])
    print('\n')
# Out:
# <p class="avatar"><a href="login" rel="nofollow"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></a></p>
#
#
# <p class="username optional">Guest</p>
#
#
# <p class="subtitle optional"><a href="login" rel="nofollow">Login</a> or <a href="register" rel="nofollow">Sign Up</a></p>
#
#
# <p class="site-title"><a href="https://www.nintendolife.com/"><img alt="Nintendo Life" src="https://images.nintendolife.com/site/logo.svg?v=2&amp;colour=e60012" width="265"/></a></p>
#
#
# <p class="avatar"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></p>
#
#
# <p><a class="username ui-user-profile" href="user/profile" rel="nofollow">Guest</a></p>
#
#
# <p class="subtitle"><a href="login" rel="nofollow">Login</a> or <a href="register" rel="nofollow">Sign Up</a></p>
#
#
# <p class="image accent-bg"><img alt="link3710" height="200" src="https://images.nintendolife.com/users/58197/200x200.jpg?v=1516306053" width="200"/></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/daemon_x_machina"><span class="title accent-hover">Daemon X Machina</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/spyro_reignited_trilogy"><span class="title accent-hover">Spyro Reignited Trilogy</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/gato_roboto"><span class="title accent-hover">Gato Roboto</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/deltarune_chapter_1"><span class="title accent-hover">DELTARUNE Chapter 1</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/super_smash_bros_ultimate"><span class="title accent-hover">Super Smash Bros. Ultimate</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/katamari_damacy_reroll"><span class="title accent-hover">Katamari Damacy REROLL</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/horizon_chase_turbo"><span class="title accent-hover">Horizon Chase Turbo</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/dragon_ball_fighterz"><span class="title accent-hover">Dragon Ball FighterZ</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">8</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/undertale"><span class="title accent-hover">Undertale</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/okami_hd"><span class="title accent-hover">Okami HD</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/yokus_island_express"><span class="title accent-hover">Yoku's Island Express</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">9</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/bayonetta_2"><span class="title accent-hover">Bayonetta 2</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/bayonetta"><span class="title accent-hover">Bayonetta</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score"><span class="value">10</span>/10</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lost_sphear"><span class="title accent-hover">Lost Sphear</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/xenoblade_chronicles_2"><span class="title accent-hover">Xenoblade Chronicles 2</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/mobile/animal_crossing_pocket_camp"><span class="title accent-hover">Animal Crossing: Pocket Camp</span> <span class="subtitle">Mobile</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/mxgp_3"><span class="title accent-hover">MXGP 3</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/superbeat_xonic"><span class="title accent-hover">Superbeat: Xonic</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lumo"><span class="title accent-hover">Lumo</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><span class="title accent-hover">Pokémon Ultra Sun and Ultra Moon</span> <span class="subtitle">3DS</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/batman_-_the_telltale_series"><span class="title accent-hover">Batman - The Telltale Series</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/ittle_dew_2plus"><span class="title accent-hover">Ittle Dew 2+</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lego_marvel_super_heroes_2"><span class="title accent-hover">LEGO Marvel Super Heroes 2</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/rocket_league"><span class="title accent-hover">Rocket League</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/doom"><span class="title accent-hover">DOOM</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/sonic_forces"><span class="title accent-hover">Sonic Forces</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/super_mario_odyssey"><span class="title accent-hover">Super Mario Odyssey</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><span class="title accent-hover">Nights of Azure 2: Bride of the New Moon</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/poi_explorer_edition"><span class="title accent-hover">Poi: Explorer Edition</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fire_emblem_warriors"><span class="title accent-hover">Fire Emblem Warriors</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/88_heroes_98_heroes_edition"><span class="title accent-hover">88 Heroes: 98 Heroes Edition</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/tiny_barbarian_dx"><span class="title accent-hover">Tiny Barbarian DX</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/oxenfree"><span class="title accent-hover">Oxenfree</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fifa_18"><span class="title accent-hover">FIFA 18</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><span class="title accent-hover">One Piece Unlimited World Red - Deluxe Edition</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/golf_story"><span class="title accent-hover">Golf Story</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/sine_mora_ex"><span class="title accent-hover">Sine Mora EX</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/dragon_ball_xenoverse_2"><span class="title accent-hover">Dragon Ball Xenoverse 2</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/steamworld_dig_2"><span class="title accent-hover">SteamWorld Dig 2</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/soldam_drop_connect_erase"><span class="title accent-hover">Soldam: Drop, Connect, Erase</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/3ds/metroid_samus_returns"><span class="title accent-hover">Metroid: Samus Returns</span> <span class="subtitle">3DS</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/rayman_legends_definitive_edition"><span class="title accent-hover">Rayman Legends: Definitive Edition</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/bridge"><span class="title accent-hover">The Bridge</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lego_worlds"><span class="title accent-hover">LEGO Worlds</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/r_b_i_baseball_17"><span class="title accent-hover">R.B.I. Baseball 17</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/mario_plus_rabbids_kingdom_battle"><span class="title accent-hover">Mario + Rabbids Kingdom Battle</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/retro_city_rampage_dx"><span class="title accent-hover">Retro City Rampage DX</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/fateextella_the_umbral_star"><span class="title accent-hover">Fate/Extella: The Umbral Star</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/splatoon_2"><span class="title accent-hover">Splatoon 2</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/death_squared"><span class="title accent-hover">Death Squared</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/cave_storyplus"><span class="title accent-hover">Cave Story+</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/arms"><span class="title accent-hover">ARMS</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/mighty_gunvolt_burst"><span class="title accent-hover">Mighty Gunvolt Burst</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/disgaea_5_complete"><span class="title accent-hover">Disgaea 5 Complete</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/thumper"><span class="title accent-hover">Thumper</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/mario_kart_8_deluxe"><span class="title accent-hover">Mario Kart 8 Deluxe</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/kamiko"><span class="title accent-hover">Kamiko</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/switch-eshop/wonder_boy_the_dragons_trap"><span class="title accent-hover">Wonder Boy: The Dragon's Trap</span> <span class="subtitle">Switch eShop</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/lego_city_undercover"><span class="title accent-hover">LEGO City: Undercover</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/has-been_heroes"><span class="title accent-hover">Has-Been Heroes</span> <span class="subtitle">Switch</span></a></p>
#
#
# <p class="description">User Score: <strong class="user-score">No Score</strong></p>
#
#
# <p class="ui-back-to-top"><a class="ui-goto-top" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-caret-up"></span></a></p>
#
#
# <p class="list-heading">Popular Right Now</p>
#
#
# <p class="image"><a href="news/2020/01/guide_super_smash_bros_ultimate_full_character_list_-_byleth_joins_the_roster"><img alt="Guide: Super Smash Bros. Ultimate Full Character List - Byleth Joins The Roster" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_super_smash_bros_ultimate_full_character_list_-_byleth_joins_the_roster/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/guide_super_smash_bros_ultimate_full_character_list_-_byleth_joins_the_roster"><abbr title="Guide: Super Smash Bros. Ultimate Full Character List - Byleth Joins The Roster">Guide: Super Smash Bros. Ultimate Full Character List - B...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-17T08:00:00+00:00"><span>Fri 17th Jan 2020</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/feature_best_nintendo_switch_couch_co-op_games"><img alt="Feature: Best Nintendo Switch Couch Co-Op Games" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/feature_best_nintendo_switch_couch_co-op_games/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/feature_best_nintendo_switch_couch_co-op_games">Feature: Best Nintendo Switch Couch Co-Op Games</a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-18T13:00:00+00:00"><span>Sat 18th Jan 2020</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/guide_pokemon_sword_and_shield_codes_full_list_of_mystery_gift_codes"><img alt="Guide: Pokémon Sword And Shield Codes: Full List Of Mystery Gift Codes" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_pokemon_sword_and_shield_codes_full_list_of_mystery_gift_codes/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/guide_pokemon_sword_and_shield_codes_full_list_of_mystery_gift_codes"><abbr title="Guide: Pokémon Sword And Shield Codes: Full List Of Mystery Gift Codes">Guide: Pokémon Sword And Shield Codes: Full List Of Myst...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-23T08:00:00+00:00"><span>4 days ago</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/random_ever_wondered_what_that_weird_blob_on_your_switch_screen_is_nintendo_explains"><img alt="Random: Ever Wondered What That Weird Blob On Your Switch Screen Is? Nintendo Explains" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/random_ever_wondered_what_that_weird_blob_on_your_switch_screen_is_nintendo_explains/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/random_ever_wondered_what_that_weird_blob_on_your_switch_screen_is_nintendo_explains"><abbr title="Random: Ever Wondered What That Weird Blob On Your Switch Screen Is? Nintendo Explains">Random: Ever Wondered What That Weird Blob On Your Switch...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-24T16:30:00+00:00"><span>2 days ago</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/random_this_skyrim_mod_makes_the_game_look_like_the_legend_of_zelda_breath_of_the_wild"><img alt="Random: This Skyrim Mod Makes The Game Look Like The Legend Of Zelda: Breath Of The Wild" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/random_this_skyrim_mod_makes_the_game_look_like_the_legend_of_zelda_breath_of_the_wild/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/random_this_skyrim_mod_makes_the_game_look_like_the_legend_of_zelda_breath_of_the_wild"><abbr title="Random: This Skyrim Mod Makes The Game Look Like The Legend Of Zelda: Breath Of The Wild">Random: This Skyrim Mod Makes The Game Look Like The Lege...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-26T13:00:00+00:00"><span>11 hours ago</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/guide_pokemon_go_how_to_evolve_eevee_into_leafeon_and_glaceon_with_or_without_a_lure_module"><img alt="Guide: Pokémon GO: How To Evolve Eevee Into Leafeon And Glaceon With Or Without A Lure Module" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_pokemon_go_how_to_evolve_eevee_into_leafeon_and_glaceon_with_or_without_a_lure_module/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/guide_pokemon_go_how_to_evolve_eevee_into_leafeon_and_glaceon_with_or_without_a_lure_module"><abbr title="Guide: Pokémon GO: How To Evolve Eevee Into Leafeon And Glaceon With Or Without A Lure Module">Guide: Pokémon GO: How To Evolve Eevee Into Leafeon And ...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-18T16:00:00+00:00"><span>Sat 18th Jan 2020</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/federal_court_rules_usd10_1_million_case_against_nintendos_wii_remote_as_invalid"><img alt="Federal Court Rules $10.1 Million Case Against Nintendo's Wii Remote As Invalid" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/federal_court_rules_usd10_1_million_case_against_nintendos_wii_remote_as_invalid/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/federal_court_rules_usd10_1_million_case_against_nintendos_wii_remote_as_invalid"><abbr title="Federal Court Rules $10.1 Million Case Against Nintendo's Wii Remote As Invalid">Federal Court Rules $10.1 Million Case Against Nintendo's...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-21T13:45:00+00:00"><span>5 days ago</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/feature_best_nintendo_switch_games_of_2019"><img alt="Feature: Best Nintendo Switch Games Of 2019" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/feature_best_nintendo_switch_games_of_2019/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/feature_best_nintendo_switch_games_of_2019">Feature: Best Nintendo Switch Games Of 2019</a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-18T12:00:00+00:00"><span>Sat 18th Jan 2020</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/guide_luigis_mansion_3_-_gem_locations_and_gem_maps_for_every_floor"><img alt="Guide: Luigi's Mansion 3 - Gem Locations And Gem Maps For Every Floor" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_luigis_mansion_3_-_gem_locations_and_gem_maps_for_every_floor/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/guide_luigis_mansion_3_-_gem_locations_and_gem_maps_for_every_floor"><abbr title="Guide: Luigi's Mansion 3 - Gem Locations And Gem Maps For Every Floor">Guide: Luigi's Mansion 3 - Gem Locations And Gem Maps For...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-18T11:00:00+00:00"><span>Sat 18th Jan 2020</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/remember_that_zelda_breath_of_the_wild_clone_that_killed_a_ps4_its_coming_to_switch"><img alt="Remember That Zelda: Breath Of The Wild Clone That Killed A PS4? It's Coming To Switch" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/remember_that_zelda_breath_of_the_wild_clone_that_killed_a_ps4_its_coming_to_switch/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/remember_that_zelda_breath_of_the_wild_clone_that_killed_a_ps4_its_coming_to_switch"><abbr title="Remember That Zelda: Breath Of The Wild Clone That Killed A PS4? It's Coming To Switch">Remember That Zelda: Breath Of The Wild Clone That Killed...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-16T15:50:00+00:00"><span>Thu 16th Jan 2020</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo"><img alt='Reggie Encouraged Nintendo To Embrace "What The Brand Stood For" By Sticking With Its Iconic Logo' class="lazy" data-original="https://images.nintendolife.com/news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo"><abbr title='Reggie Encouraged Nintendo To Embrace "What The Brand Stood For" By Sticking With Its Iconic Logo'>Reggie Encouraged Nintendo To Embrace "What The Brand Sto...</abbr></a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-26T06:55:00+00:00"><span>17 hours ago</span></time></p>
#
#
# <p class="image"><a href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far"><img alt="Guide: Nintendo Switch Pro: Everything We Know So Far" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a></p>
#
#
# <p class="heading"><a class="accent" href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far">Guide: Nintendo Switch Pro: Everything We Know So Far</a></p>
#
#
# <p class="date"><span class="icon icon-time"></span> <time class="date age" datetime="2020-01-23T06:00:00+00:00"><span>4 days ago</span></time></p>
#
#
# <p class="more"><a class="accent-hover" href="news">Show More <span class="icon icon-caret-down"></span></a></p>
#
#
# <p class="text">Join <strong>913,836</strong> people following <strong>Nintendo Life</strong>:</p>
#
#
# <p class="copyright">© 2020 <a href="https://nlife.com" rel="external">Nlife Media</a>, partner of <a href="https://www.gamer-network.net" rel="external">Gamer Network</a>. Hosted by <a href="https://www.44bytes.net/">44 Bytes</a>.</p>

# %% [markdown]
# It looks like I need to find every p where class = "heading" or class = "description" - how can I do that?

# %%
games[10]
# Out:
# <p class="heading"><a class="title accent-hover" href="games/nintendo-switch/spyro_reignited_trilogy"><span class="title accent-hover">Spyro Reignited Trilogy</span> <span class="subtitle">Switch</span></a></p>

# %%
type(games[10])
# Out:
# bs4.element.Tag

# %%
games[10].name
# Out:
# 'p'

# %%
games[10].attrs
# Out:
# {'class': ['heading']}

# %%
soup.a
# Out:
# <a class="ui-toggle-overlay" data-overlay="sidebar" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-bars"></span><span class="label">Menu</span></a>

# %%
soup.findAll("a")
# Out:
# [<a class="ui-toggle-overlay" data-overlay="sidebar" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-bars"></span><span class="label">Menu</span></a>,
#  <a class="ui-toggle-search" href="search" rel="nofollow"><span class="icon icon-search"></span><span class="label">Search</span></a>,
#  <a class="ui-share-page optional" href="share" rel="nofollow" title="Share This Page"><span class="icon icon-share"></span> <span class="label">Share</span></a>,
#  <a class="ui-share-page whatsapp" data-service="whatsapp" href="#" rel="nofollow" title="Share this page on WhatsApp"><span class="icon icon-whatsapp"></span></a>,
#  <a class="ui-share-page messenger for-mobile" data-service="fbmessenger" href="#" rel="nofollow" title="Share this page on Facebook Messenger"><span class="icon icon-messenger"></span></a>,
#  <a class="ui-share-page facebook" data-service="facebook" href="#" rel="nofollow" title="Share this page on Facebook"><span class="icon icon-facebook"></span></a>,
#  <a class="ui-share-page twitter" data-service="twitter" href="#" rel="nofollow" title="Share this page on Twitter"><span class="icon icon-twitter"></span></a>,
#  <a class="ui-share-page skype" data-service="skype" href="#" rel="nofollow" title="Share this page on Skype"><span class="icon icon-skype"></span></a>,
#  <a class="ui-share-page reddit for-desktop" data-service="reddit" href="#" rel="nofollow" title="Share this page on reddit"><span class="icon icon-reddit"></span></a>,
#  <a href="login" rel="nofollow"><img alt="Guest" src="https://static.nintendolife.com/themes/nl.v10/images/avatar.jpg"/></a>,
#  <a href="login" rel="nofollow">Login</a>,
#  <a href="register" rel="nofollow">Sign Up</a>,
#  <a href="https://www.nintendolife.com/"><img alt="Nintendo Life" src="https://images.nintendolife.com/site/logo.svg?v=2&amp;colour=e60012" width="265"/></a>,
#  <a class="main-menu-item" href="https://www.nintendolife.com/" title="Home"><span class="icon icon-wiiu-home"></span> <span class="label">Home</span></a>,
#  <a class="main-menu-item no-icon" data-name="topics" href="topics"><span class="label ui-topic-title">Topics</span> <span class="icon icon-caret-down"></span></a>,
#  <a class="main-menu-item" data-name="news" href="/news"><span class="icon icon-news optional"></span> <span class="label">News</span></a>,
#  <a class="main-menu-item" data-name="reviews" href="/reviews"><span class="icon icon-reviews optional"></span> <span class="label">Reviews</span></a>,
#  <a class="main-menu-item" data-name="features" href="/features"><span class="icon icon-features optional"></span> <span class="label">Features</span></a>,
#  <a class="main-menu-item" data-name="games" href="/games/browse"><span class="icon icon-books optional"></span> <span class="label">Games</span></a>,
#  <a class="main-menu-item" data-name="guides" href="/guides"><span class="icon icon-map optional"></span> <span class="label">Guides</span></a>,
#  <a class="main-menu-item external" href="https://www.youtube.com/nintendolife"><span class="icon icon-videos optional"></span> <span class="label">Videos</span></a>,
#  <a class="main-menu-item" data-name="forums" href="/forums"><span class="icon icon-comments optional"></span> <span class="label">Forums</span></a>,
#  <a class="username ui-user-profile" href="user/profile" rel="nofollow">Guest</a>,
#  <a href="login" rel="nofollow">Login</a>,
#  <a href="register" rel="nofollow">Sign Up</a>,
#  <a class="ui-user-notifications" href="user/notifications" rel="nofollow" title="Number of unread notifications"><span class="icon icon-notification"></span> <span class="label">Notifications</span> <span class="counter accent-bg">0</span></a>,
#  <a class="ui-user-games" href="user/games" rel="nofollow"><span class="icon icon-books"></span> <span class="label">Games Collection</span> <span class="icon icon-angle-right right"></span></a>,
#  <a class="ui-user-profile" href="user/profile" rel="nofollow"><span class="icon icon-profile"></span> <span class="label">View Profile</span> <span class="icon icon-angle-right right"></span></a>,
#  <a href="user" rel="nofollow"><span class="icon icon-settings"></span> <span class="label">Your Account</span> <span class="icon icon-angle-right right"></span></a>,
#  <a href="logout" rel="nofollow"><span class="icon icon-logout"></span> <span class="label">Logout</span> <span class="icon icon-angle-right right"></span></a>,
#  <a href="https://www.nintendolife.com/"><span class="icon icon-wiiu-home"></span> <span class="label">Home</span> <span class="icon icon-angle-right right"></span></a>,
#  <a href="topics" rel="nofollow"><span class="icon icon-topic"></span> <span class="label">Choose Topics...</span> <span class="icon icon-angle-right right"></span></a>,
#  <a href="topics" rel="nofollow"><span class="icon icon-settings"></span> <span class="label">Manage Topics</span> <span class="icon icon-angle-right right"></span></a>,
#  <a href="/users/link3710">link3710</a>,
#  <a href="/users/link3710">Profile</a>,
#  <a class="current" href="/users/link3710/games">Games</a>,
#  <a href="/users/link3710/comments">Comments</a>,
#  <a href="/users/link3710/topics">Discussions</a>,
#  <a href="login">Posts</a>,
#  <a class="selected accent accent-border" data-view="games" href="users/link3710/games#games">Games</a>,
#  <a class="img" href="games/nintendo-switch/daemon_x_machina"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/daemon_x_machina/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/daemon_x_machina"><span class="title accent-hover">Daemon X Machina</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/spyro_reignited_trilogy"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/spyro_reignited_trilogy/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/spyro_reignited_trilogy"><span class="title accent-hover">Spyro Reignited Trilogy</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/gato_roboto"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/gato_roboto/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/gato_roboto"><span class="title accent-hover">Gato Roboto</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/switch-eshop/deltarune_chapter_1"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/deltarune_chapter_1/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/deltarune_chapter_1"><span class="title accent-hover">DELTARUNE Chapter 1</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/super_smash_bros_ultimate"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/super_smash_bros_ultimate/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/super_smash_bros_ultimate"><span class="title accent-hover">Super Smash Bros. Ultimate</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/katamari_damacy_reroll"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/katamari_damacy_reroll/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/katamari_damacy_reroll"><span class="title accent-hover">Katamari Damacy REROLL</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/switch-eshop/horizon_chase_turbo"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/horizon_chase_turbo/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/horizon_chase_turbo"><span class="title accent-hover">Horizon Chase Turbo</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/dragon_ball_fighterz"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/dragon_ball_fighterz/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/dragon_ball_fighterz"><span class="title accent-hover">Dragon Ball FighterZ</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/undertale"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/undertale/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/undertale"><span class="title accent-hover">Undertale</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/switch-eshop/okami_hd"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/okami_hd/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/okami_hd"><span class="title accent-hover">Okami HD</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/switch-eshop/yokus_island_express"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/yokus_island_express/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/yokus_island_express"><span class="title accent-hover">Yoku's Island Express</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/bayonetta_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/bayonetta_2/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/bayonetta_2"><span class="title accent-hover">Bayonetta 2</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/bayonetta"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/bayonetta/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/bayonetta"><span class="title accent-hover">Bayonetta</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/lost_sphear"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lost_sphear/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/lost_sphear"><span class="title accent-hover">Lost Sphear</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/xenoblade_chronicles_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/xenoblade_chronicles_2/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/xenoblade_chronicles_2"><span class="title accent-hover">Xenoblade Chronicles 2</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/mobile/animal_crossing_pocket_camp"><img alt="" height="122" src="https://images.nintendolife.com/games/mobile/animal_crossing_pocket_camp/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/mobile/animal_crossing_pocket_camp"><span class="title accent-hover">Animal Crossing: Pocket Camp</span> <span class="subtitle">Mobile</span></a>,
#  <a class="img" href="games/nintendo-switch/mxgp_3"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/mxgp_3/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/mxgp_3"><span class="title accent-hover">MXGP 3</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/superbeat_xonic"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/superbeat_xonic/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/superbeat_xonic"><span class="title accent-hover">Superbeat: Xonic</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/lumo"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lumo/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/lumo"><span class="title accent-hover">Lumo</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><img alt="" height="122" src="https://images.nintendolife.com/games/3ds/pokemon_ultra_sun_and_ultra_moon/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/3ds/pokemon_ultra_sun_and_ultra_moon"><span class="title accent-hover">Pokémon Ultra Sun and Ultra Moon</span> <span class="subtitle">3DS</span></a>,
#  <a class="img" href="games/nintendo-switch/batman_-_the_telltale_series"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/batman_-_the_telltale_series/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/batman_-_the_telltale_series"><span class="title accent-hover">Batman - The Telltale Series</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/ittle_dew_2plus"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/ittle_dew_2plus/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/ittle_dew_2plus"><span class="title accent-hover">Ittle Dew 2+</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/lego_marvel_super_heroes_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lego_marvel_super_heroes_2/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/lego_marvel_super_heroes_2"><span class="title accent-hover">LEGO Marvel Super Heroes 2</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/rocket_league"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/rocket_league/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/rocket_league"><span class="title accent-hover">Rocket League</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/doom"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/doom/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/doom"><span class="title accent-hover">DOOM</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/sonic_forces"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/sonic_forces/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/sonic_forces"><span class="title accent-hover">Sonic Forces</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/super_mario_odyssey"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/super_mario_odyssey/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/super_mario_odyssey"><span class="title accent-hover">Super Mario Odyssey</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/nights_of_azure_2_bride_of_the_new_moon"><span class="title accent-hover">Nights of Azure 2: Bride of the New Moon</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/poi_explorer_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/poi_explorer_edition/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/poi_explorer_edition"><span class="title accent-hover">Poi: Explorer Edition</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/fire_emblem_warriors"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fire_emblem_warriors/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/fire_emblem_warriors"><span class="title accent-hover">Fire Emblem Warriors</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/88_heroes_98_heroes_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/88_heroes_98_heroes_edition/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/88_heroes_98_heroes_edition"><span class="title accent-hover">88 Heroes: 98 Heroes Edition</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/tiny_barbarian_dx"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/tiny_barbarian_dx/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/tiny_barbarian_dx"><span class="title accent-hover">Tiny Barbarian DX</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/oxenfree"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/oxenfree/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/oxenfree"><span class="title accent-hover">Oxenfree</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/fifa_18"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fifa_18/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/fifa_18"><span class="title accent-hover">FIFA 18</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/one_piece_unlimited_world_red_-_deluxe_edition"><span class="title accent-hover">One Piece Unlimited World Red - Deluxe Edition</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/golf_story"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/golf_story/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/golf_story"><span class="title accent-hover">Golf Story</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/sine_mora_ex"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/sine_mora_ex/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/sine_mora_ex"><span class="title accent-hover">Sine Mora EX</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/dragon_ball_xenoverse_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/dragon_ball_xenoverse_2/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/dragon_ball_xenoverse_2"><span class="title accent-hover">Dragon Ball Xenoverse 2</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/steamworld_dig_2"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/steamworld_dig_2/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/steamworld_dig_2"><span class="title accent-hover">SteamWorld Dig 2</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/soldam_drop_connect_erase"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/soldam_drop_connect_erase/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/soldam_drop_connect_erase"><span class="title accent-hover">Soldam: Drop, Connect, Erase</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/3ds/metroid_samus_returns"><img alt="" height="122" src="https://images.nintendolife.com/games/3ds/metroid_samus_returns/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/3ds/metroid_samus_returns"><span class="title accent-hover">Metroid: Samus Returns</span> <span class="subtitle">3DS</span></a>,
#  <a class="img" href="games/nintendo-switch/rayman_legends_definitive_edition"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/rayman_legends_definitive_edition/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/rayman_legends_definitive_edition"><span class="title accent-hover">Rayman Legends: Definitive Edition</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/bridge"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/bridge/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/bridge"><span class="title accent-hover">The Bridge</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/lego_worlds"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lego_worlds/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/lego_worlds"><span class="title accent-hover">LEGO Worlds</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/r_b_i_baseball_17"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/r_b_i_baseball_17/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/r_b_i_baseball_17"><span class="title accent-hover">R.B.I. Baseball 17</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/mario_plus_rabbids_kingdom_battle"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/mario_plus_rabbids_kingdom_battle/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/mario_plus_rabbids_kingdom_battle"><span class="title accent-hover">Mario + Rabbids Kingdom Battle</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/retro_city_rampage_dx"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/retro_city_rampage_dx/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/retro_city_rampage_dx"><span class="title accent-hover">Retro City Rampage DX</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/fateextella_the_umbral_star"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/fateextella_the_umbral_star/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/fateextella_the_umbral_star"><span class="title accent-hover">Fate/Extella: The Umbral Star</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/splatoon_2"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/splatoon_2/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/splatoon_2"><span class="title accent-hover">Splatoon 2</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/death_squared"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/death_squared/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/death_squared"><span class="title accent-hover">Death Squared</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/cave_storyplus"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/cave_storyplus/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/cave_storyplus"><span class="title accent-hover">Cave Story+</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/arms"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/arms/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/arms"><span class="title accent-hover">ARMS</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/mighty_gunvolt_burst"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/mighty_gunvolt_burst/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/mighty_gunvolt_burst"><span class="title accent-hover">Mighty Gunvolt Burst</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/disgaea_5_complete"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/disgaea_5_complete/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/disgaea_5_complete"><span class="title accent-hover">Disgaea 5 Complete</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/thumper"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/thumper/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/thumper"><span class="title accent-hover">Thumper</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/mario_kart_8_deluxe"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/mario_kart_8_deluxe/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/mario_kart_8_deluxe"><span class="title accent-hover">Mario Kart 8 Deluxe</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/switch-eshop/kamiko"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/kamiko/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/kamiko"><span class="title accent-hover">Kamiko</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/switch-eshop/wonder_boy_the_dragons_trap"><img alt="" height="122" src="https://images.nintendolife.com/games/switch-eshop/wonder_boy_the_dragons_trap/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/switch-eshop/wonder_boy_the_dragons_trap"><span class="title accent-hover">Wonder Boy: The Dragon's Trap</span> <span class="subtitle">Switch eShop</span></a>,
#  <a class="img" href="games/nintendo-switch/lego_city_undercover"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/lego_city_undercover/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/lego_city_undercover"><span class="title accent-hover">LEGO City: Undercover</span> <span class="subtitle">Switch</span></a>,
#  <a class="img" href="games/nintendo-switch/has-been_heroes"><img alt="" height="122" src="https://images.nintendolife.com/games/nintendo-switch/has-been_heroes/220x122.jpg" width="220"/></a>,
#  <a class="title accent-hover" href="games/nintendo-switch/has-been_heroes"><span class="title accent-hover">Has-Been Heroes</span> <span class="subtitle">Switch</span></a>,
#  <a class="active accent-bg accent-border" href="/users/link3710/games" title="Goto Page 1">1</a>,
#  <a class="accent accent-bg-hover accent-border" href="/users/link3710/games?page=2" title="Goto Page 2">2</a>,
#  <a class="accent accent-bg-hover accent-border" href="/users/link3710/games?page=3" title="Goto Page 3">3</a>,
#  <a class="accent accent-bg-hover accent-border" href="/users/link3710/games?page=4" title="Goto Page 4">4</a>,
#  <a class="ui-goto-top" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-caret-up"></span></a>,
#  <a href="letter/a">A</a>,
#  <a href="letter/b">B</a>,
#  <a href="letter/c">C</a>,
#  <a href="letter/d">D</a>,
#  <a href="letter/e">E</a>,
#  <a href="letter/f">F</a>,
#  <a href="letter/g">G</a>,
#  <a href="letter/h">H</a>,
#  <a href="letter/i">I</a>,
#  <a href="letter/j">J</a>,
#  <a href="letter/k">K</a>,
#  <a href="letter/l">L</a>,
#  <a href="letter/m">M</a>,
#  <a href="letter/n">N</a>,
#  <a href="letter/o">O</a>,
#  <a href="letter/p">P</a>,
#  <a href="letter/q">Q</a>,
#  <a href="letter/r">R</a>,
#  <a href="letter/s">S</a>,
#  <a href="letter/t">T</a>,
#  <a href="letter/u">U</a>,
#  <a href="letter/v">V</a>,
#  <a href="letter/w">W</a>,
#  <a href="letter/x">X</a>,
#  <a href="letter/y">Y</a>,
#  <a href="letter/z">Z</a>,
#  <a href="about">About Us</a>,
#  <a href="staff">Staff</a>,
#  <a href="archive">Archive</a>,
#  <a href="scoring">Scoring Policy</a>,
#  <a href="privacy">Privacy &amp; Cookies</a>,
#  <a href="advertising">Advertising Policy</a>,
#  <a href="terms">Terms of Use</a>,
#  <a href="developers">Developers</a>,
#  <a href="contact">Contact</a>,
#  <a href="desktop" rel="nofollow">Desktop Version</a>,
#  <a class="ui-goto-top" href="https://www.nintendolife.com/" rel="nofollow"><span class="icon icon-caret-up"></span> Top</a>,
#  <a href="news/2020/01/guide_super_smash_bros_ultimate_full_character_list_-_byleth_joins_the_roster"><img alt="Guide: Super Smash Bros. Ultimate Full Character List - Byleth Joins The Roster" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_super_smash_bros_ultimate_full_character_list_-_byleth_joins_the_roster/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/guide_super_smash_bros_ultimate_full_character_list_-_byleth_joins_the_roster"><abbr title="Guide: Super Smash Bros. Ultimate Full Character List - Byleth Joins The Roster">Guide: Super Smash Bros. Ultimate Full Character List - B...</abbr></a>,
#  <a href="news/2020/01/feature_best_nintendo_switch_couch_co-op_games"><img alt="Feature: Best Nintendo Switch Couch Co-Op Games" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/feature_best_nintendo_switch_couch_co-op_games/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/feature_best_nintendo_switch_couch_co-op_games">Feature: Best Nintendo Switch Couch Co-Op Games</a>,
#  <a href="news/2020/01/guide_pokemon_sword_and_shield_codes_full_list_of_mystery_gift_codes"><img alt="Guide: Pokémon Sword And Shield Codes: Full List Of Mystery Gift Codes" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_pokemon_sword_and_shield_codes_full_list_of_mystery_gift_codes/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/guide_pokemon_sword_and_shield_codes_full_list_of_mystery_gift_codes"><abbr title="Guide: Pokémon Sword And Shield Codes: Full List Of Mystery Gift Codes">Guide: Pokémon Sword And Shield Codes: Full List Of Myst...</abbr></a>,
#  <a href="news/2020/01/random_ever_wondered_what_that_weird_blob_on_your_switch_screen_is_nintendo_explains"><img alt="Random: Ever Wondered What That Weird Blob On Your Switch Screen Is? Nintendo Explains" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/random_ever_wondered_what_that_weird_blob_on_your_switch_screen_is_nintendo_explains/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/random_ever_wondered_what_that_weird_blob_on_your_switch_screen_is_nintendo_explains"><abbr title="Random: Ever Wondered What That Weird Blob On Your Switch Screen Is? Nintendo Explains">Random: Ever Wondered What That Weird Blob On Your Switch...</abbr></a>,
#  <a href="news/2020/01/random_this_skyrim_mod_makes_the_game_look_like_the_legend_of_zelda_breath_of_the_wild"><img alt="Random: This Skyrim Mod Makes The Game Look Like The Legend Of Zelda: Breath Of The Wild" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/random_this_skyrim_mod_makes_the_game_look_like_the_legend_of_zelda_breath_of_the_wild/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/random_this_skyrim_mod_makes_the_game_look_like_the_legend_of_zelda_breath_of_the_wild"><abbr title="Random: This Skyrim Mod Makes The Game Look Like The Legend Of Zelda: Breath Of The Wild">Random: This Skyrim Mod Makes The Game Look Like The Lege...</abbr></a>,
#  <a href="news/2020/01/guide_pokemon_go_how_to_evolve_eevee_into_leafeon_and_glaceon_with_or_without_a_lure_module"><img alt="Guide: Pokémon GO: How To Evolve Eevee Into Leafeon And Glaceon With Or Without A Lure Module" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_pokemon_go_how_to_evolve_eevee_into_leafeon_and_glaceon_with_or_without_a_lure_module/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/guide_pokemon_go_how_to_evolve_eevee_into_leafeon_and_glaceon_with_or_without_a_lure_module"><abbr title="Guide: Pokémon GO: How To Evolve Eevee Into Leafeon And Glaceon With Or Without A Lure Module">Guide: Pokémon GO: How To Evolve Eevee Into Leafeon And ...</abbr></a>,
#  <a href="news/2020/01/federal_court_rules_usd10_1_million_case_against_nintendos_wii_remote_as_invalid"><img alt="Federal Court Rules $10.1 Million Case Against Nintendo's Wii Remote As Invalid" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/federal_court_rules_usd10_1_million_case_against_nintendos_wii_remote_as_invalid/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/federal_court_rules_usd10_1_million_case_against_nintendos_wii_remote_as_invalid"><abbr title="Federal Court Rules $10.1 Million Case Against Nintendo's Wii Remote As Invalid">Federal Court Rules $10.1 Million Case Against Nintendo's...</abbr></a>,
#  <a href="news/2020/01/feature_best_nintendo_switch_games_of_2019"><img alt="Feature: Best Nintendo Switch Games Of 2019" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/feature_best_nintendo_switch_games_of_2019/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/feature_best_nintendo_switch_games_of_2019">Feature: Best Nintendo Switch Games Of 2019</a>,
#  <a href="news/2020/01/guide_luigis_mansion_3_-_gem_locations_and_gem_maps_for_every_floor"><img alt="Guide: Luigi's Mansion 3 - Gem Locations And Gem Maps For Every Floor" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_luigis_mansion_3_-_gem_locations_and_gem_maps_for_every_floor/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/guide_luigis_mansion_3_-_gem_locations_and_gem_maps_for_every_floor"><abbr title="Guide: Luigi's Mansion 3 - Gem Locations And Gem Maps For Every Floor">Guide: Luigi's Mansion 3 - Gem Locations And Gem Maps For...</abbr></a>,
#  <a href="news/2020/01/remember_that_zelda_breath_of_the_wild_clone_that_killed_a_ps4_its_coming_to_switch"><img alt="Remember That Zelda: Breath Of The Wild Clone That Killed A PS4? It's Coming To Switch" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/remember_that_zelda_breath_of_the_wild_clone_that_killed_a_ps4_its_coming_to_switch/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/remember_that_zelda_breath_of_the_wild_clone_that_killed_a_ps4_its_coming_to_switch"><abbr title="Remember That Zelda: Breath Of The Wild Clone That Killed A PS4? It's Coming To Switch">Remember That Zelda: Breath Of The Wild Clone That Killed...</abbr></a>,
#  <a href="news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo"><img alt='Reggie Encouraged Nintendo To Embrace "What The Brand Stood For" By Sticking With Its Iconic Logo' class="lazy" data-original="https://images.nintendolife.com/news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/reggie_encouraged_nintendo_to_embrace_what_the_brand_stood_for_by_sticking_with_its_iconic_logo"><abbr title='Reggie Encouraged Nintendo To Embrace "What The Brand Stood For" By Sticking With Its Iconic Logo'>Reggie Encouraged Nintendo To Embrace "What The Brand Sto...</abbr></a>,
#  <a href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far"><img alt="Guide: Nintendo Switch Pro: Everything We Know So Far" class="lazy" data-original="https://images.nintendolife.com/news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far/130x100.jpg" height="100" src="https://static.nintendolife.com/blank.gif" width="130"/></a>,
#  <a class="accent" href="news/2020/01/guide_nintendo_switch_pro_everything_we_know_so_far">Guide: Nintendo Switch Pro: Everything We Know So Far</a>,
#  <a class="accent-hover" href="news">Show More <span class="icon icon-caret-down"></span></a>,
#  <a class="ui-social-feed" data-username="latest" href="https://www.nintendolife.com/feeds/latest" rel="external" title="Subscribe to our RSS Feed"><span class="icon icon-feed"></span> <span class="label">RSS Feed</span></a>,
#  <a class="ui-social-twitter" data-username="nintendolife" href="https://twitter.com/nintendolife" rel="external" title="Nintendo Life on Twitter"><span class="icon icon-twitter"></span> <span class="label">Twitter</span></a>,
#  <a class="ui-social-facebook" data-username="nintendolife" href="https://www.facebook.com/nintendolife" rel="external" title="Nintendo Life on Facebook"><span class="icon icon-facebook"></span> <span class="label">Facebook</span></a>,
#  <a class="ui-social-youtube" data-username="nintendolife" href="https://www.youtube.com/nintendolife" rel="external" title="Nintendo Life on YouTube"><span class="icon icon-youtube"></span> <span class="label">YouTube</span></a>,
#  <a class="ui-social-instagram" data-username="nintendolife" href="https://www.instagram.com/nintendolife/" rel="external" title="Nintendo Life on Instagram"><span class="icon icon-instagram"></span> <span class="label">Instagram</span></a>,
#  <a class="ui-social-deviantart" data-username="nintendolife" href="https://www.deviantart.com/nintendolife" rel="external" title="Nintendo Life on DeviantArt"><span class="icon icon-deviantart"></span> <span class="label">DeviantArt</span></a>,
#  <a href="https://nlife.com" rel="external">Nlife Media</a>,
#  <a href="https://www.gamer-network.net" rel="external">Gamer Network</a>,
#  <a href="https://www.44bytes.net/">44 Bytes</a>,
#  <a href="https://nintendonews.com" rel="external" title="Nintendo News - All the latest Nintendo News from across the web.">Nintendo News</a>,
#  <a href="https://www.pushsquare.com" rel="external" title="Push Square - covering everything PlayStation including PS Vita &amp; PS3 news and reviews.">Push Square</a>,
#  <a href="https://www.eurogamer.net" rel="external" title="European coverage of the world of gaming - the mighty Eurogamer.net">Eurogamer.net</a>,
#  <a href="https://www.usgamer.net" rel="external" title="US coverage of the world of gaming - it's USgamer">USgamer</a>,
#  <a href="https://www.videogameschronicle.com" rel="external" title="The latest news from Video Games Chronicle">VGC</a>,
#  <a href="https://www.rockpapershotgun.com" rel="external" title="Specialist PC gaming blog - Rock, Paper, Shotgun">Rock, Paper, Shotgun</a>,
#  <a href="https://www.vg247.com" rel="external" title="Up to the minute news coverage for all formats - VG24/7">VG247</a>,
#  <a href="https://www.gamesindustry.biz" rel="external" title="Stay on the pulse with industry news with the #1 resource - GamesIndustry.biz">GamesIndustry.biz</a>]

# %% [markdown]
# Seems like all of the game titles are in the a class and the game descriptions are in the p class

# %%
game_titles = soup.findAll("a")

# %%
game_titles[42].attrs
# Out:
# {'class': ['img'], 'href': 'games/nintendo-switch/spyro_reignited_trilogy'}

# %%
spans = soup.findAll("span")

# %%
spans
# Out:
# [<span class="icon icon-bars"></span>,
#  <span class="label">Menu</span>,
#  <span class="icon icon-search"></span>,
#  <span class="label">Search</span>,
#  <span class="icon icon-share"></span>,
#  <span class="label">Share</span>,
#  <span class="icon icon-whatsapp"></span>,
#  <span class="icon icon-messenger"></span>,
#  <span class="icon icon-facebook"></span>,
#  <span class="icon icon-twitter"></span>,
#  <span class="icon icon-skype"></span>,
#  <span class="icon icon-reddit"></span>,
#  <span class="icon icon-wiiu-home"></span>,
#  <span class="label">Home</span>,
#  <span class="label ui-topic-title">Topics</span>,
#  <span class="icon icon-caret-down"></span>,
#  <span class="icon icon-news optional"></span>,
#  <span class="label">News</span>,
#  <span class="icon icon-reviews optional"></span>,
#  <span class="label">Reviews</span>,
#  <span class="icon icon-features optional"></span>,
#  <span class="label">Features</span>,
#  <span class="icon icon-books optional"></span>,
#  <span class="label">Games</span>,
#  <span class="icon icon-map optional"></span>,
#  <span class="label">Guides</span>,
#  <span class="icon icon-videos optional"></span>,
#  <span class="label">Videos</span>,
#  <span class="icon icon-comments optional"></span>,
#  <span class="label">Forums</span>,
#  <span class="icon icon-notification"></span>,
#  <span class="label">Notifications</span>,
#  <span class="counter accent-bg">0</span>,
#  <span class="icon icon-books"></span>,
#  <span class="label">Games Collection</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-profile"></span>,
#  <span class="label">View Profile</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-settings"></span>,
#  <span class="label">Your Account</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-logout"></span>,
#  <span class="label">Logout</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-wiiu-home"></span>,
#  <span class="label">Home</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-topic"></span>,
#  <span class="label">Choose Topics...</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-settings"></span>,
#  <span class="label">Manage Topics</span>,
#  <span class="icon icon-angle-right right"></span>,
#  <span class="icon icon-caret-down"></span>,
#  <span class="icon icon-caret-down"></span>,
#  <span class="fm-checkbox fm-checkbox-selected"><input checked="checked" class="radio" id="status-opt1" name="status[]" type="checkbox" value="own"> <label class="checkbox" for="status-opt1">Have <span class="count">189</span></label></input></span>,
#  <span class="count">189</span>,
#  <span class="fm-checkbox"><input class="radio" id="status-opt2" name="status[]" type="checkbox" value="owned"/> <label class="checkbox" for="status-opt2">Owned <span class="count">2</span></label></span>,
#  <span class="count">2</span>,
#  <span class="fm-checkbox"><input class="radio" id="status-opt3" name="status[]" type="checkbox" value="want"/> <label class="checkbox" for="status-opt3">Want <span class="count">103</span></label></span>,
#  <span class="count">103</span>,
#  <span class="fm-checkbox"><input class="radio" id="status-opt4" name="status[]" type="checkbox" value="maybe"/> <label class="checkbox" for="status-opt4">Maybe <span class="count">124</span></label></span>,
#  <span class="count">124</span>,
#  <span class="fm-checkbox"><input class="radio" id="status-opt5" name="status[]" type="checkbox" value="not-interested"/> <label class="checkbox" for="status-opt5">Nope! <span class="count">86</span></label></span>,
#  <span class="count">86</span>,
#  <span class="icon icon-caret-left"></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt1" name="score[]" type="checkbox" value="10"/> <label class="checkbox" for="score-opt1">10/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt2" name="score[]" type="checkbox" value="9"/> <label class="checkbox" for="score-opt2">9/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt3" name="score[]" type="checkbox" value="8"/> <label class="checkbox" for="score-opt3">8/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt4" name="score[]" type="checkbox" value="7"/> <label class="checkbox" for="score-opt4">7/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt5" name="score[]" type="checkbox" value="6"/> <label class="checkbox" for="score-opt5">6/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt6" name="score[]" type="checkbox" value="5"/> <label class="checkbox" for="score-opt6">5/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt7" name="score[]" type="checkbox" value="4"/> <label class="checkbox" for="score-opt7">4/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt8" name="score[]" type="checkbox" value="3"/> <label class="checkbox" for="score-opt8">3/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt9" name="score[]" type="checkbox" value="2"/> <label class="checkbox" for="score-opt9">2/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt10" name="score[]" type="checkbox" value="1"/> <label class="checkbox" for="score-opt10">1/10</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="score-opt11" name="score[]" type="checkbox" value="none"/> <label class="checkbox" for="score-opt11">No Score</label></span>,
#  <span class="icon icon-caret-left"></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt1" name="system[]" type="checkbox" value="systems/3ds"/> <label class="checkbox" for="system-opt1">3DS (157)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt2" name="system[]" type="checkbox" value="systems/nintendo-switch"/> <label class="checkbox" for="system-opt2">Switch (156)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt3" name="system[]" type="checkbox" value="systems/switch-eshop"/> <label class="checkbox" for="system-opt3">Switch eShop (80)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt4" name="system[]" type="checkbox" value="systems/wiiu"/> <label class="checkbox" for="system-opt4">Wii U (38)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt5" name="system[]" type="checkbox" value="systems/gameboy"/> <label class="checkbox" for="system-opt5">GB (18)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt6" name="system[]" type="checkbox" value="systems/wii"/> <label class="checkbox" for="system-opt6">Wii (16)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt7" name="system[]" type="checkbox" value="systems/ds"/> <label class="checkbox" for="system-opt7">DS (10)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt8" name="system[]" type="checkbox" value="systems/new-3ds"/> <label class="checkbox" for="system-opt8">New 3DS (10)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt9" name="system[]" type="checkbox" value="systems/3ds-eshop"/> <label class="checkbox" for="system-opt9">3DS eShop (6)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt10" name="system[]" type="checkbox" value="systems/gamecube"/> <label class="checkbox" for="system-opt10">GCN (6)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt11" name="system[]" type="checkbox" value="systems/wiiu-eshop"/> <label class="checkbox" for="system-opt11">Wii U eShop (4)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt12" name="system[]" type="checkbox" value="systems/gbc"/> <label class="checkbox" for="system-opt12">GBC (2)</label></span>,
#  <span class="fm-checkbox"><input class="radio" id="system-opt13" name="system[]" type="checkbox" value="systems/mobile"/> <label class="checkbox" for="system-opt13">Mobile (1)</label></span>,
#  <span class="title accent-hover">Daemon X Machina</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Spyro Reignited Trilogy</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="value">9</span>,
#  <span class="title accent-hover">Gato Roboto</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">8</span>,
#  <span class="title accent-hover">DELTARUNE Chapter 1</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">9</span>,
#  <span class="title accent-hover">Super Smash Bros. Ultimate</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="value">10</span>,
#  <span class="title accent-hover">Katamari Damacy REROLL</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">9</span>,
#  <span class="title accent-hover">Horizon Chase Turbo</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">8</span>,
#  <span class="title accent-hover">Dragon Ball FighterZ</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="value">8</span>,
#  <span class="title accent-hover">Undertale</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">9</span>,
#  <span class="title accent-hover">Okami HD</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">9</span>,
#  <span class="title accent-hover">Yoku's Island Express</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">9</span>,
#  <span class="title accent-hover">Bayonetta 2</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="value">10</span>,
#  <span class="title accent-hover">Bayonetta</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="value">10</span>,
#  <span class="title accent-hover">Lost Sphear</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Xenoblade Chronicles 2</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Animal Crossing: Pocket Camp</span>,
#  <span class="subtitle">Mobile</span>,
#  <span class="title accent-hover">MXGP 3</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Superbeat: Xonic</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Lumo</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Pokémon Ultra Sun and Ultra Moon</span>,
#  <span class="subtitle">3DS</span>,
#  <span class="title accent-hover">Batman - The Telltale Series</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Ittle Dew 2+</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">LEGO Marvel Super Heroes 2</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Rocket League</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">DOOM</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Sonic Forces</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Super Mario Odyssey</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Nights of Azure 2: Bride of the New Moon</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Poi: Explorer Edition</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Fire Emblem Warriors</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">88 Heroes: 98 Heroes Edition</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Tiny Barbarian DX</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Oxenfree</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">FIFA 18</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">One Piece Unlimited World Red - Deluxe Edition</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Golf Story</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Sine Mora EX</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Dragon Ball Xenoverse 2</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">SteamWorld Dig 2</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Soldam: Drop, Connect, Erase</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Metroid: Samus Returns</span>,
#  <span class="subtitle">3DS</span>,
#  <span class="title accent-hover">Rayman Legends: Definitive Edition</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">The Bridge</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">LEGO Worlds</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">R.B.I. Baseball 17</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Mario + Rabbids Kingdom Battle</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Retro City Rampage DX</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Fate/Extella: The Umbral Star</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Splatoon 2</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Death Squared</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Cave Story+</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">ARMS</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Mighty Gunvolt Burst</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Disgaea 5 Complete</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Thumper</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Mario Kart 8 Deluxe</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Kamiko</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">Wonder Boy: The Dragon's Trap</span>,
#  <span class="subtitle">Switch eShop</span>,
#  <span class="title accent-hover">LEGO City: Undercover</span>,
#  <span class="subtitle">Switch</span>,
#  <span class="title accent-hover">Has-Been Heroes</span>,
#  <span class="subtitle">Switch</span>,
#  <span>Page :</span>,
#  <span class="icon icon-caret-up"></span>,
#  <span class="icon icon-caret-up"></span>,
#  <span class="icon icon-time"></span>,
#  <span>Fri 17th Jan 2020</span>,
#  <span class="icon icon-time"></span>,
#  <span>Sat 18th Jan 2020</span>,
#  <span class="icon icon-time"></span>,
#  <span>4 days ago</span>,
#  <span class="icon icon-time"></span>,
#  <span>2 days ago</span>,
#  <span class="icon icon-time"></span>,
#  <span>11 hours ago</span>,
#  <span class="icon icon-time"></span>,
#  <span>Sat 18th Jan 2020</span>,
#  <span class="icon icon-time"></span>,
#  <span>5 days ago</span>,
#  <span class="icon icon-time"></span>,
#  <span>Sat 18th Jan 2020</span>,
#  <span class="icon icon-time"></span>,
#  <span>Sat 18th Jan 2020</span>,
#  <span class="icon icon-time"></span>,
#  <span>Thu 16th Jan 2020</span>,
#  <span class="icon icon-time"></span>,
#  <span>17 hours ago</span>,
#  <span class="icon icon-time"></span>,
#  <span>4 days ago</span>,
#  <span class="icon icon-caret-down"></span>,
#  <span class="icon icon-feed"></span>,
#  <span class="label">RSS Feed</span>,
#  <span class="icon icon-twitter"></span>,
#  <span class="label">Twitter</span>,
#  <span class="icon icon-facebook"></span>,
#  <span class="label">Facebook</span>,
#  <span class="icon icon-youtube"></span>,
#  <span class="label">YouTube</span>,
#  <span class="icon icon-instagram"></span>,
#  <span class="label">Instagram</span>,
#  <span class="icon icon-deviantart"></span>,
#  <span class="label">DeviantArt</span>]

# %%
spans[94].contents[0]
# Out:
# 'Spyro Reignited Trilogy'

# %%
spans[96].contents[0]
# Out:
# '9'

# %%
spans[94]
# Out:
# <span class="title accent-hover">Spyro Reignited Trilogy</span>

# %%
spans[94].attrs
# Out:
# {'class': ['title', 'accent-hover']}

# %%
if spans[94]["class"] == ['title', 'accent-hover']:
    print(True)
# Out:
# True

# %%
spans[95]
# Out:
# <span class="subtitle">Switch</span>

# %%
spans[95].attrs
# Out:
# {'class': ['subtitle']}

# %%
if spans[95]["class"] == ["subtitle"]: 
    print(True)
else:
    print(False)
# Out:
# True

# %%
spans[96]
# Out:
# <span class="value">9</span>

# %%
spans[96].attrs
# Out:
# {'class': ['value']}

# %%
spans[94].contents
# Out:
# ['Spyro Reignited Trilogy']

# %%
spans[96].contents
# Out:
# ['9']

# %%
#I'm going to set up a dataframe with 3 columns - user, game and rating

cols = ["User", "Game", "Rating"]

df = pd.DataFrame(columns = cols)

# %%
len(spans)
# Out:
# 264

# %%
games = []
ratings = []

for i in range(len(spans)):
    try:
        if spans[i]["class"] == ["title", "accent-hover"]:
            games.append(spans[i].contents[0])
            if spans[i+2]["class"] == ["value"]:
                ratings.append(spans[i+2].contents[0])
            else:
                ratings.append("No Score")
    except KeyError:
        pass
    
if len(games) > len(ratings):
    ratings.append("No Score")

# %%
print(games)
print(ratings)
# Out:
# ['Daemon X Machina', 'Spyro Reignited Trilogy', 'Gato Roboto', 'DELTARUNE Chapter 1', 'Super Smash Bros. Ultimate', 'Katamari Damacy REROLL', 'Horizon Chase Turbo', 'Dragon Ball FighterZ', 'Undertale', 'Okami HD', "Yoku's Island Express", 'Bayonetta 2', 'Bayonetta', 'Lost Sphear', 'Xenoblade Chronicles 2', 'Animal Crossing: Pocket Camp', 'MXGP 3', 'Superbeat: Xonic', 'Lumo', 'Pokémon Ultra Sun and Ultra Moon', 'Batman - The Telltale Series', 'Ittle Dew 2+', 'LEGO Marvel Super Heroes 2', 'Rocket League', 'DOOM', 'Sonic Forces', 'Super Mario Odyssey', 'Nights of Azure 2: Bride of the New Moon', 'Poi: Explorer Edition', 'Fire Emblem Warriors', '88 Heroes: 98 Heroes Edition', 'Tiny Barbarian DX', 'Oxenfree', 'FIFA 18', 'One Piece Unlimited World Red - Deluxe Edition', 'Golf Story', 'Sine Mora EX', 'Dragon Ball Xenoverse 2', 'SteamWorld Dig 2', 'Soldam: Drop, Connect, Erase', 'Metroid: Samus Returns', 'Rayman Legends: Definitive Edition', 'The Bridge', 'LEGO Worlds', 'R.B.I. Baseball 17', 'Mario + Rabbids Kingdom Battle', 'Retro City Rampage DX', 'Fate/Extella: The Umbral Star', 'Splatoon 2', 'Death Squared', 'Cave Story+', 'ARMS', 'Mighty Gunvolt Burst', 'Disgaea 5 Complete', 'Thumper', 'Mario Kart 8 Deluxe', 'Kamiko', "Wonder Boy: The Dragon's Trap", 'LEGO City: Undercover', 'Has-Been Heroes']
# ['No Score', '9', '8', '9', '10', '9', '8', '8', '9', '9', '9', '10', '10', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score', 'No Score']

# %%
df["Game"] = games
df["Rating"] = ratings

# %%
df["User"] = "link3710"

# %%
df.head(10)
# Out:
#        User                        Game    Rating
# 0  link3710            Daemon X Machina  No Score
# 1  link3710     Spyro Reignited Trilogy         9
# 2  link3710                 Gato Roboto         8
# 3  link3710         DELTARUNE Chapter 1         9
# 4  link3710  Super Smash Bros. Ultimate        10
# 5  link3710      Katamari Damacy REROLL         9
# 6  link3710         Horizon Chase Turbo         8
# 7  link3710        Dragon Ball FighterZ         8
# 8  link3710                   Undertale         9
# 9  link3710                    Okami HD         9

# %% [markdown]
# Next Steps: Figure out pagination, figure out how to pull multiple users

# %% [markdown]
# The pagination element of the page is tagged in the following manner: <br>
# "< nav class ="ui-listing-pagination" > <br>
# There are then child tags equal to the number of pages that a given user has, with the last page tagged as follows: <br>
# < li class = "last" > <br>
# Within that last class is contained a class that looks like this: <br>
# < a class="accent accent-bg-hover accent-border" href="/users/link3710/games?sort=date&amp;status=own&amp;style=tile&amp;page=4" title="Goto Page 4">4</ a>
# <br>
# I need to get the contents of that last tag out.

# %%
#last tag
my_page_tags = soup.findAll("a", {"class": "accent accent-bg-hover accent-border"})

# %%
my_page_tags
# Out:
# [<a class="accent accent-bg-hover accent-border" href="/users/link3710/games?page=2" title="Goto Page 2">2</a>,
#  <a class="accent accent-bg-hover accent-border" href="/users/link3710/games?page=3" title="Goto Page 3">3</a>,
#  <a class="accent accent-bg-hover accent-border" href="/users/link3710/games?page=4" title="Goto Page 4">4</a>]

# %%
page_tags = []
for tag in my_page_tags:
    page_tags.append(int(tag.contents[0]))
    
print(page_tags)
# Out:
# [2, 3, 4]

# %%
max_page_tags = max(page_tags)

# %%
max_page_tags = int(max_page_tags)

# %%
max_page_tags
# Out:
# 4

# %%
max_page_tags * 2
# Out:
# 8

# %% [markdown]
# In order to get the data for multiple users, I'll have to have the usernames stored in another object prior to requesting my pages, so for now, I'm not going to worry about programmatically retrieving the username from a given user's page.

# %%
#Creating Function for getting max pages

def get_max_pages(user_name):
    '''Function for getting the maximum number of pages of games
       from our user page'''
    
    #Setting parameters and getting soup for our user
    url = "https://www.nintendolife.com/users/" + user_name + "/games"
    r = requests.get(url) 
    html_text = r.text
    soup = BeautifulSoup(html_text, "html.parser")

    #try-except block for if a user only has one page
    try:
        pagination_tags = soup.findAll("a", {"class": "accent accent-bg-hover accent-border"}) #just pagination tags
        page_tag_numbers = []
        for tag in pagination_tags:
            page_tag_numbers.append(int(tag.contents[0]))
        max_page_tag = max(page_tag_numbers)
        return max_page_tag
    
    except:
        max_page_tag = 1
        return max_page_tag

# %%
print(get_max_pages("link3710"))
# Out:
# 4

# %%
#Creating Function for getting games and ratings into dataframe=
def games_ratings_to_df(user_name, max_pages):
    '''Function for putting a user's games
    and ratings into a dataframe'''
    
    #Setting up object holders
    cols = ["User", "Game", "Rating"]
    df = pd.DataFrame(columns=cols)
    games = []
    ratings = []
    
    #iterating through pages
    for page in range(1, max_pages+1):
        #Url is different if on first page rather than other pages
        if page == 1:
            #Setting parameters and getting first soup for our user
            url = "https://www.nintendolife.com/users/" + user_name + "/games"
            r = requests.get(url) 
            html_text = r.text
            soup = BeautifulSoup(html_text, "html.parser")
            
            #Getting our game tags
            spans = soup.findAll("span")
            for i in range(len(spans)):
                #Try-except block for key-errors when filtering for class
                try:
                    #conditional for just tag types that are holding game titles
                    if spans[i]["class"] == ["title", "accent-hover"]:
                        games.append(spans[i].contents[0])
                        #Conditional for putting rating or no score - can explain how
                        if spans[i+2]["class"] == ["value"]:
                            ratings.append(spans[i+2].contents[0])
                        else:
                            ratings.append("No Score")
                except KeyError:
                    pass
            #appending no score for last game (if last game had no score)
            if len(games) > len(ratings):
                ratings.append("No Score")
        #Adding the rest of the url pages       
        else:
            #Setting parameters and getting first soup for our user
            url = "https://www.nintendolife.com/users/" + user_name + "/games?page=" + str(page)
            r = requests.get(url) 
            html_text = r.text
            soup = BeautifulSoup(html_text, "html.parser")
            
            #Getting our game tags
            spans = soup.findAll("span")
            for i in range(len(spans)):
                #Try-except block for key-errors when filtering for class
                try:
                    #conditional for just tag types that are holding game titles
                    if spans[i]["class"] == ["title", "accent-hover"]:
                        games.append(spans[i].contents[0])
                        #Conditional for putting rating or no score - can explain how
                        if spans[i+2]["class"] == ["value"]:
                            ratings.append(spans[i+2].contents[0])
                        else:
                            ratings.append("No Score")
                except KeyError:
                    pass
            #appending no score for last game (if last game had no score)
            if len(games) > len(ratings):
                ratings.append("No Score")
    
    #Adding our games and ratings list to dataframe
    df["Game"] = games
    df["Rating"] = ratings
    df["User"] = user_name
    
    return df

# %%
link3710_ratings = games_ratings_to_df("link3710", 4)
print(link3710_ratings.head(10))
print(link3710_ratings.shape)
# Out:
#        User                        Game    Rating
# 0  link3710            Daemon X Machina  No Score
# 1  link3710     Spyro Reignited Trilogy         9
# 2  link3710                 Gato Roboto         8
# 3  link3710         DELTARUNE Chapter 1         9
# 4  link3710  Super Smash Bros. Ultimate        10
# 5  link3710      Katamari Damacy REROLL         9
# 6  link3710         Horizon Chase Turbo         8
# 7  link3710        Dragon Ball FighterZ         8
# 8  link3710                   Undertale         9
# 9  link3710                    Okami HD         9
# (189, 3)

# %%
link3710_pages = get_max_pages("link3710")
link3710_ratings = games_ratings_to_df("link3710", link3710_pages)

# %%
link3710_ratings.head(10)
# Out:
#        User                        Game    Rating
# 0  link3710            Daemon X Machina  No Score
# 1  link3710     Spyro Reignited Trilogy         9
# 2  link3710                 Gato Roboto         8
# 3  link3710         DELTARUNE Chapter 1         9
# 4  link3710  Super Smash Bros. Ultimate        10
# 5  link3710      Katamari Damacy REROLL         9
# 6  link3710         Horizon Chase Turbo         8
# 7  link3710        Dragon Ball FighterZ         8
# 8  link3710                   Undertale         9
# 9  link3710                    Okami HD         9

# %%
link3710_ratings.tail(10)
# Out:
#          User                                   Game Rating
# 179  link3710                            Donkey Kong     10
# 180  link3710  The Legend of Zelda: Link's Awakening     10
# 181  link3710                     Kirby's Dream Land      7
# 182  link3710                Final Fantasy Adventure      7
# 183  link3710                Final Fantasy Legend II      8
# 184  link3710               The Hunt for Red October      9
# 185  link3710                              Dr. Mario      8
# 186  link3710                       Gargoyle's Quest      7
# 187  link3710                                    QIX      8
# 188  link3710         Pinball: Revenge of the 'Gator      9
